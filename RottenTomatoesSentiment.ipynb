# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import re
import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer

# %%
train_df = pd.read_csv('train.tsv',header=0,delimiter='\t',quoting=3)

train_df.head()
# Out:
#    PhraseId  ...  Sentiment
# 0         1  ...          1
# 1         2  ...          2
# 2         3  ...          2
# 3         4  ...          2
# 4         5  ...          2
#
# [5 rows x 4 columns]

# %%
train_df['Phrase'][0]
# Out:
# 'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .'

# %%
train_df['Phrase'][1]
# Out:
# 'A series of escapades demonstrating the adage that what is good for the goose'

# %%
test_df = pd.read_csv('test.tsv',header=0,delimiter='\t',quoting=3)

test_df.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156062        8545  An intermittently pleasing but mostly routine ...
# 2    156063        8545                                                 An
# 3    156064        8545  intermittently pleasing but mostly routine effort
# 4    156065        8545         intermittently pleasing but mostly routine

# %%
train_df['Phrase'].head(20)
# Out:
# 0     A series of escapades demonstrating the adage ...
# 1     A series of escapades demonstrating the adage ...
# 2                                              A series
# 3                                                     A
# 4                                                series
# 5     of escapades demonstrating the adage that what...
# 6                                                    of
# 7     escapades demonstrating the adage that what is...
# 8                                             escapades
# 9     demonstrating the adage that what is good for ...
# 10                              demonstrating the adage
# 11                                        demonstrating
# 12                                            the adage
# 13                                                  the
# 14                                                adage
# 15                      that what is good for the goose
# 16                                                 that
# 17                           what is good for the goose
# 18                                                 what
# 19                                is good for the goose
# Name: Phrase, dtype: object

# %%
pd.options.display.max_colwidth = 500

# %%
train_df['Phrase'].head(50)
# Out:
# 0     A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .
# 1                                                                                                                    A series of escapades demonstrating the adage that what is good for the goose
# 2                                                                                                                                                                                         A series
# 3                                                                                                                                                                                                A
# 4                                                                                                                                                                                           series
# 5                                                                                                                             of escapades demonstrating the adage that what is good for the goose
# 6                                                                                                                                                                                               of
# 7                                                                                                                                escapades demonstrating the adage that what is good for the goose
# 8                                                                                                                                                                                        escapades
# 9                                                                                                                                          demonstrating the adage that what is good for the goose
# 10                                                                                                                                                                         demonstrating the adage
# 11                                                                                                                                                                                   demonstrating
# 12                                                                                                                                                                                       the adage
# 13                                                                                                                                                                                             the
# 14                                                                                                                                                                                           adage
# 15                                                                                                                                                                 that what is good for the goose
# 16                                                                                                                                                                                            that
# 17                                                                                                                                                                      what is good for the goose
# 18                                                                                                                                                                                            what
# 19                                                                                                                                                                           is good for the goose
# 20                                                                                                                                                                                              is
# 21                                                                                                                                                                              good for the goose
# 22                                                                                                                                                                                            good
# 23                                                                                                                                                                                   for the goose
# 24                                                                                                                                                                                             for
# 25                                                                                                                                                                                       the goose
# 26                                                                                                                                                                                           goose
# 27                                                                                  is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .
# 28                                                                                    is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story
# 29                                                                                                                                                                                         is also
# 30                                                                                                                                                                                            also
# 31                                                                                            good for the gander , some of which occasionally amuses but none of which amounts to much of a story
# 32                                                                                                 for the gander , some of which occasionally amuses but none of which amounts to much of a story
# 33                                                                                                     the gander , some of which occasionally amuses but none of which amounts to much of a story
# 34                                                                                                                                                                                    the gander ,
# 35                                                                                                                                                                                      the gander
# 36                                                                                                                                                                                          gander
# 37                                                                                                                                                                                               ,
# 38                                                                                                                  some of which occasionally amuses but none of which amounts to much of a story
# 39                                                                                                                                                                                   some of which
# 40                                                                                                                                                                                            some
# 41                                                                                                                                                                                        of which
# 42                                                                                                                                                                                           which
# 43                                                                                                                                occasionally amuses but none of which amounts to much of a story
# 44                                                                                                                                                                                    occasionally
# 45                                                                                                                                             amuses but none of which amounts to much of a story
# 46                                                                                                                                                                                          amuses
# 47                                                                                                                                                    but none of which amounts to much of a story
# 48                                                                                                                                                                                             but
# 49                                                                                                                                                        none of which amounts to much of a story
# Name: Phrase, dtype: object

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
len(train_df)
# Out:
# 156060

# %%
len(test_df)
# Out:
# 66292

# %%
def clean_words(raw_words):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    text = BeautifulSoup(raw_words).get_text()
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
clean_words(train_df['Phrase'][0])
# Out:
# 'series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story'

# %%
train_df['Phrase'][0]
# Out:
# 'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .'

# %%
length = len(train_df['Phrase'])

length
# Out:
# 156060

# %%
cleaned_phrases = []

for i in range(0, length):
  cleaned_phrases.append(clean_words(train_df['Phrase'][i]))
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
cleaned_phrases
# Out:
# ['series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story',
#  'series escapades demonstrating adage good goose',
#  'series',
#  '',
#  'series',
#  'escapades demonstrating adage good goose',
#  '',
#  'escapades demonstrating adage good goose',
#  'escapades',
#  'demonstrating adage good goose',
#  'demonstrating adage',
#  'demonstrating',
#  'adage',
#  '',
#  'adage',
#  'good goose',
#  '',
#  'good goose',
#  '',
#  'good goose',
#  '',
#  'good goose',
#  'good',
#  'goose',
#  '',
#  'goose',
#  'goose',
#  'also good gander occasionally amuses none amounts much story',
#  'also good gander occasionally amuses none amounts much story',
#  'also',
#  'also',
#  'good gander occasionally amuses none amounts much story',
#  'gander occasionally amuses none amounts much story',
#  'gander occasionally amuses none amounts much story',
#  'gander',
#  'gander',
#  'gander',
#  '',
#  'occasionally amuses none amounts much story',
#  '',
#  '',
#  '',
#  '',
#  'occasionally amuses none amounts much story',
#  'occasionally',
#  'amuses none amounts much story',
#  'amuses',
#  'none amounts much story',
#  '',
#  'none amounts much story',
#  'none',
#  'amounts much story',
#  'amounts much story',
#  'amounts much story',
#  'amounts',
#  'much story',
#  '',
#  'much story',
#  'much',
#  'story',
#  'story',
#  'story',
#  '',
#  'quiet introspective entertaining independent worth seeking',
#  'quiet introspective entertaining independent',
#  '',
#  'quiet introspective entertaining independent',
#  'quiet introspective entertaining',
#  'quiet',
#  'introspective entertaining',
#  'introspective entertaining',
#  'introspective',
#  'introspective',
#  '',
#  'entertaining',
#  'independent',
#  'worth seeking',
#  'worth seeking',
#  'worth',
#  'worth',
#  'seeking',
#  'even fans ismail merchant work suspect would hard time sitting one',
#  'even fans ismail merchant work',
#  'even fans',
#  'even',
#  'fans',
#  'ismail merchant work',
#  'ismail merchant work',
#  'ismail merchant',
#  'ismail',
#  'merchant',
#  'merchant',
#  '',
#  'work',
#  'suspect would hard time sitting one',
#  'suspect',
#  'suspect',
#  'suspect',
#  '',
#  'suspect',
#  'would hard time sitting one',
#  'would hard time sitting one',
#  'would',
#  'hard time sitting one',
#  '',
#  'hard time sitting one',
#  'hard time',
#  'hard time',
#  'hard',
#  'time',
#  'sitting one',
#  'sitting',
#  'one',
#  '',
#  'one',
#  'one',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder',
#  'positively thrilling combination',
#  'positively thrilling combination',
#  'positively',
#  'thrilling combination',
#  'thrilling',
#  'combination',
#  'ethnography intrigue betrayal deceit murder',
#  'ethnography intrigue betrayal deceit murder',
#  'ethnography',
#  'ethnography',
#  'intrigue betrayal deceit murder',
#  '',
#  'intrigue betrayal deceit murder',
#  'intrigue betrayal deceit murder',
#  'intrigue',
#  'betrayal deceit murder',
#  'betrayal deceit murder',
#  'betrayal',
#  'deceit murder',
#  'deceit murder',
#  'deceit',
#  'deceit',
#  'murder',
#  'shakespearean tragedy juicy soap opera',
#  'shakespearean tragedy juicy soap opera',
#  'shakespearean tragedy',
#  'shakespearean tragedy',
#  'shakespearean tragedy',
#  'shakespearean',
#  'tragedy',
#  '',
#  'juicy soap opera',
#  'juicy soap opera',
#  'juicy',
#  'soap opera',
#  'soap',
#  'opera',
#  'aggressive self glorification manipulative whitewash',
#  'aggressive self glorification manipulative whitewash',
#  'aggressive',
#  'self glorification manipulative whitewash',
#  'self glorification',
#  'self glorification',
#  'manipulative whitewash',
#  'manipulative whitewash',
#  'manipulative',
#  'whitewash',
#  'comedy drama nearly epic proportions rooted sincere performance title character undergoing midlife crisis',
#  'comedy drama nearly epic proportions',
#  'comedy drama',
#  'comedy drama',
#  'nearly epic proportions',
#  'nearly epic proportions',
#  'nearly epic',
#  'nearly',
#  'epic',
#  'proportions',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'rooted sincere performance',
#  'rooted',
#  'sincere performance',
#  '',
#  'sincere performance',
#  'sincere performance',
#  'sincere',
#  'performance',
#  'title character undergoing midlife crisis',
#  '',
#  'title character undergoing midlife crisis',
#  'title character',
#  'title character',
#  'title',
#  'character',
#  'undergoing midlife crisis',
#  'undergoing',
#  'midlife crisis',
#  'midlife',
#  'crisis',
#  'narratively trouble every day plodding mess',
#  'narratively',
#  'trouble every day plodding mess',
#  'trouble every day plodding mess',
#  'trouble every day',
#  'trouble',
#  'every day',
#  'every',
#  'day',
#  'plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'plodding',
#  'mess',
#  'importance earnest thick wit plays like reading bartlett familiar quotations',
#  'importance',
#  'importance',
#  'earnest thick wit plays like reading bartlett familiar quotations',
#  'earnest thick wit plays like reading bartlett familiar quotations',
#  '',
#  'earnest thick wit plays like reading bartlett familiar quotations',
#  'earnest',
#  'earnest',
#  'thick wit plays like reading bartlett familiar quotations',
#  '',
#  'thick wit plays like reading bartlett familiar quotations',
#  'thick',
#  'wit plays like reading bartlett familiar quotations',
#  '',
#  'wit plays like reading bartlett familiar quotations',
#  'wit',
#  'plays like reading bartlett familiar quotations',
#  '',
#  'plays like reading bartlett familiar quotations',
#  'plays',
#  'like reading bartlett familiar quotations',
#  'like',
#  'reading bartlett familiar quotations',
#  'reading',
#  'reading',
#  'bartlett familiar quotations',
#  '',
#  'bartlett familiar quotations',
#  'bartlett',
#  'bartlett',
#  'familiar quotations',
#  'familiar',
#  'quotations',
#  'n leave much',
#  'n leave much',
#  'n leave much',
#  'n leave much',
#  'n',
#  '',
#  'n',
#  'leave much',
#  'leave',
#  'leave',
#  '',
#  'much',
#  'could hate reason',
#  'could hate reason',
#  'could hate reason',
#  'could',
#  'hate reason',
#  'hate',
#  'hate',
#  'reason',
#  'reason',
#  'reason',
#  '',
#  'reason',
#  'little recommend snow dogs unless one considers cliched dialogue perverse escapism source high hilarity',
#  '',
#  'little recommend snow dogs unless one considers cliched dialogue perverse escapism source high hilarity',
#  'little recommend snow dogs unless one considers cliched dialogue perverse escapism source high hilarity',
#  'little recommend snow dogs',
#  'little recommend snow dogs',
#  'little recommend snow dogs',
#  'little',
#  'recommend snow dogs',
#  'recommend snow dogs',
#  'recommend',
#  'snow dogs',
#  'snow',
#  'dogs',
#  'unless one considers cliched dialogue perverse escapism source high hilarity',
#  'unless',
#  'one considers cliched dialogue perverse escapism source high hilarity',
#  'considers cliched dialogue perverse escapism source high hilarity',
#  'considers',
#  'cliched dialogue perverse escapism source high hilarity',
#  'cliched dialogue perverse escapism',
#  'cliched dialogue',
#  'cliched dialogue',
#  'cliched',
#  'dialogue',
#  'perverse escapism',
#  'perverse',
#  'escapism',
#  'source high hilarity',
#  'source',
#  'source',
#  'high hilarity',
#  'high hilarity',
#  'high',
#  'hilarity',
#  'kung pow oedekerk realization childhood dream martial arts flick proves sometimes dreams youth remain',
#  'kung pow',
#  'kung',
#  'pow',
#  'oedekerk realization childhood dream martial arts flick proves sometimes dreams youth remain',
#  'oedekerk realization childhood dream martial arts flick proves sometimes dreams youth remain',
#  'oedekerk realization childhood dream martial arts flick',
#  'oedekerk realization childhood dream martial arts flick',
#  'oedekerk realization childhood dream martial arts flick',
#  'oedekerk realization childhood dream martial arts flick',
#  'oedekerk realization childhood dream',
#  'oedekerk realization',
#  'oedekerk',
#  'oedekerk',
#  'realization',
#  'childhood dream',
#  'childhood dream',
#  '',
#  'childhood dream',
#  'childhood',
#  'dream',
#  'martial arts flick',
#  'martial arts flick',
#  '',
#  'martial arts flick',
#  'martial arts flick',
#  'martial arts flick',
#  'martial arts',
#  'flick',
#  'proves sometimes dreams youth remain',
#  'proves',
#  'sometimes dreams youth remain',
#  'sometimes dreams youth remain',
#  'sometimes',
#  'dreams youth remain',
#  'dreams youth',
#  'dreams',
#  'dreams',
#  'youth',
#  'youth',
#  'remain',
#  '',
#  'remain',
#  'remain',
#  '',
#  '',
#  'performances absolute joy',
#  'performances',
#  'performances',
#  'absolute joy',
#  'absolute joy',
#  '',
#  'absolute joy',
#  '',
#  'absolute joy',
#  'absolute',
#  'joy',
#  'fresnadillo something serious say ways extravagant chance distort perspective throw us path good sense',
#  'fresnadillo',
#  'something serious say ways extravagant chance distort perspective throw us path good sense',
#  'something serious say ways extravagant chance distort perspective throw us path good sense',
#  '',
#  'something serious say ways extravagant chance distort perspective throw us path good sense',
#  'something',
#  'serious say ways extravagant chance distort perspective throw us path good sense',
#  'serious',
#  'say ways extravagant chance distort perspective throw us path good sense',
#  'say ways extravagant chance distort perspective throw us path good sense',
#  'say',
#  'ways extravagant chance distort perspective throw us path good sense',
#  '',
#  'ways extravagant chance distort perspective throw us path good sense',
#  'ways',
#  'ways',
#  'extravagant chance distort perspective throw us path good sense',
#  '',
#  'extravagant chance distort perspective throw us path good sense',
#  'extravagant chance',
#  'extravagant',
#  'chance',
#  'distort perspective throw us path good sense',
#  '',
#  'distort perspective throw us path good sense',
#  'distort perspective',
#  'distort perspective',
#  'distort',
#  'perspective',
#  '',
#  'perspective',
#  'throw us path good sense',
#  'throw us',
#  'throw',
#  'us',
#  'path good sense',
#  '',
#  'path good sense',
#  'path',
#  'path',
#  'good sense',
#  'good sense',
#  'sense',
#  'still like moonlight mile better judgment damned',
#  'still like moonlight mile better judgment damned',
#  'still',
#  'like moonlight mile better judgment damned',
#  'like moonlight mile better judgment damned',
#  'moonlight mile better judgment damned',
#  'moonlight mile better judgment',
#  'moonlight',
#  'mile better judgment',
#  'mile',
#  'better judgment',
#  'better judgment',
#  'better',
#  'judgment',
#  'damned',
#  'damned',
#  'welcome relief baseball movies try hard mythic one sweet modest ultimately winning story',
#  'welcome relief baseball movies try hard mythic',
#  'welcome relief',
#  'welcome relief',
#  'welcome',
#  'relief',
#  'baseball movies try hard mythic',
#  'baseball movies try hard mythic',
#  'baseball movies',
#  'baseball',
#  'movies',
#  'try hard mythic',
#  'try hard mythic',
#  'try',
#  'hard mythic',
#  '',
#  'hard mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'one sweet modest ultimately winning story',
#  'one sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest',
#  'sweet modest',
#  'sweet modest',
#  'sweet',
#  'sweet',
#  'modest',
#  'ultimately winning story',
#  'ultimately',
#  'winning story',
#  'winning',
#  'bilingual charmer like woman inspired',
#  'bilingual charmer',
#  'bilingual charmer',
#  'bilingual charmer',
#  'bilingual',
#  'charmer',
#  'like woman inspired',
#  'like woman inspired',
#  'woman inspired',
#  'woman',
#  'woman',
#  'inspired',
#  '',
#  'inspired',
#  'inspired',
#  'like less dizzily gorgeous companion mr wong mood love much hong kong movie despite mainland setting',
#  'like less dizzily gorgeous companion mr',
#  'less dizzily gorgeous companion mr',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous',
#  'less',
#  'dizzily gorgeous',
#  'dizzily',
#  'gorgeous',
#  'companion',
#  'mr',
#  'mr',
#  'wong mood love much hong kong movie despite mainland setting',
#  'wong',
#  'mood love much hong kong movie despite mainland setting',
#  'mood love much hong kong movie despite mainland setting',
#  'mood love much hong kong movie',
#  'mood love much hong kong movie',
#  'mood love much hong kong movie',
#  'mood',
#  'mood',
#  'love much hong kong movie',
#  'love much hong kong movie',
#  'love much',
#  'love',
#  'love',
#  '',
#  'much',
#  '',
#  'hong kong movie',
#  'hong kong movie',
#  'hong',
#  'kong movie',
#  'kong',
#  'movie',
#  'despite mainland setting',
#  'despite',
#  'mainland setting',
#  '',
#  'mainland setting',
#  'mainland',
#  'setting',
#  'inept big screen remakes avengers wild wild west',
#  'inept big screen remakes avengers wild wild west',
#  'inept',
#  '',
#  'inept',
#  'big screen remakes avengers wild wild west',
#  'big screen remakes avengers wild wild west',
#  'big screen remakes',
#  'big screen',
#  'remakes',
#  'avengers wild wild west',
#  'avengers wild wild west',
#  'avengers',
#  'avengers',
#  'avengers',
#  'wild wild west',
#  'wild wild west',
#  'wild',
#  'wild west',
#  'west',
#  'everything expect nothing',
#  'everything expect nothing',
#  'everything expect nothing',
#  'everything expect nothing',
#  'everything',
#  'expect nothing',
#  'expect nothing',
#  '',
#  'expect nothing',
#  'expect nothing',
#  'expect',
#  'expect',
#  'nothing',
#  'nothing',
#  '',
#  'best indie year far',
#  'best',
#  'indie year far',
#  'indie year far',
#  'indie year',
#  'indie year',
#  'indie',
#  'year',
#  'year',
#  'year',
#  'far',
#  'far',
#  'hatfield hicks make oddest couples sense movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'hatfield hicks make oddest couples sense movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'hatfield hicks make oddest couples',
#  'hatfield hicks make oddest couples',
#  'hatfield hicks make oddest couples',
#  'hatfield hicks',
#  'hatfield',
#  'hatfield',
#  'hicks',
#  'make oddest couples',
#  'make',
#  'oddest couples',
#  'oddest',
#  'oddest',
#  'couples',
#  'couples',
#  'sense movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'sense',
#  'sense',
#  'movie becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'movie',
#  'becomes study gambles publishing world offering case study exists apart movie political ramifications',
#  'becomes study gambles publishing world',
#  'becomes study gambles publishing world',
#  'becomes',
#  'study gambles publishing world',
#  'study',
#  'study',
#  'gambles publishing world',
#  'gambles publishing world',
#  'gambles',
#  'gambles',
#  'publishing world',
#  'publishing world',
#  'publishing world',
#  'publishing',
#  'world',
#  'offering case study exists apart movie political ramifications',
#  'offering',
#  'case study exists apart movie political ramifications',
#  'case study',
#  'case study',
#  'case',
#  'exists apart movie political ramifications',
#  'exists apart movie political ramifications',
#  'exists apart',
#  'exists',
#  'apart',
#  'movie political ramifications',
#  'movie political ramifications',
#  'movie political ramifications',
#  'movie',
#  'movie',
#  'political ramifications',
#  'political',
#  'ramifications',
#  'like going house party watching host defend frothing ex girlfriend',
#  'like going house party watching host defend frothing ex girlfriend',
#  'like going house party watching host defend frothing ex girlfriend',
#  'like going house party watching host defend frothing ex girlfriend',
#  'going house party watching host defend frothing ex girlfriend',
#  'going house party',
#  'going house party',
#  'going',
#  'house party',
#  'house party',
#  'house party',
#  'house',
#  'party',
#  'watching host defend frothing ex girlfriend',
#  'watching',
#  'host defend frothing ex girlfriend',
#  'host',
#  'host',
#  'defend frothing ex girlfriend',
#  'defend',
#  'defend',
#  '',
#  'frothing ex girlfriend',
#  '',
#  'frothing ex girlfriend',
#  'frothing ex girlfriend',
#  'frothing',
#  'ex girlfriend',
#  'chuck norris grenade gag occurs times windtalkers good indication serious minded film',
#  'chuck norris grenade gag',
#  'chuck norris grenade gag',
#  'chuck norris grenade gag',
#  'chuck',
#  'norris grenade gag',
#  'norris',
#  'grenade gag',
#  '',
#  'grenade gag',
#  'grenade',
#  'gag',
#  'gag',
#  '',
#  'occurs times windtalkers good indication serious minded film',
#  'occurs times windtalkers good indication serious minded film',
#  'occurs',
#  'times windtalkers good indication serious minded film',
#  'times windtalkers',
#  'times',
#  'times',
#  '',
#  'times',
#  'windtalkers',
#  '',
#  'windtalkers',
#  'good indication serious minded film',
#  'good indication serious minded film',
#  'good indication',
#  'good indication',
#  'indication',
#  'serious minded film',
#  'serious minded film',
#  '',
#  'serious minded film',
#  'serious minded film',
#  'serious minded',
#  'film',
#  'film',
#  'plot romantic comedy boilerplate start finish',
#  'plot',
#  'plot',
#  'romantic comedy boilerplate start finish',
#  'romantic comedy boilerplate start finish',
#  'romantic comedy boilerplate start finish',
#  'romantic comedy boilerplate start',
#  'romantic comedy boilerplate',
#  'romantic',
#  'comedy boilerplate',
#  'comedy',
#  'boilerplate',
#  'start',
#  'start',
#  'finish',
#  'finish',
#  'arrives impeccable pedigree mongrel pep almost indecipherable plot complications',
#  'arrives impeccable pedigree mongrel pep almost indecipherable plot complications',
#  'arrives impeccable pedigree mongrel pep almost indecipherable plot complications',
#  'arrives',
#  'impeccable pedigree mongrel pep almost indecipherable plot complications',
#  'impeccable pedigree mongrel pep almost indecipherable plot complications',
#  'impeccable pedigree mongrel pep almost',
#  'impeccable pedigree mongrel pep',
#  'impeccable pedigree mongrel pep',
#  'impeccable pedigree mongrel pep',
#  'impeccable pedigree mongrel pep',
#  'impeccable',
#  'pedigree mongrel pep',
#  'pedigree',
#  'mongrel pep',
#  'mongrel pep',
#  'mongrel',
#  'pep',
#  'almost',
#  'indecipherable plot complications',
#  'indecipherable',
#  'plot complications',
#  'complications',
#  'film clearly means preach exclusively converted',
#  'film clearly means',
#  'film',
#  'clearly means',
#  'clearly means',
#  'clearly',
#  'means',
#  'means',
#  'preach exclusively converted',
#  'preach exclusively converted',
#  'preach exclusively',
#  'preach',
#  'exclusively',
#  'converted',
#  'converted',
#  'converted',
#  'importance earnest offers opportunities occasional smiles chuckles n give us reason theater beyond wilde wit actors performances',
#  'importance earnest offers opportunities occasional smiles chuckles',
#  '',
#  'importance earnest offers opportunities occasional smiles chuckles',
#  'importance earnest',
#  'earnest',
#  'earnest',
#  'offers opportunities occasional smiles chuckles',
#  'offers opportunities occasional smiles',
#  'offers opportunities occasional smiles',
#  'offers',
#  'opportunities occasional smiles',
#  'opportunities',
#  'occasional smiles',
#  'occasional smiles',
#  'occasional',
#  'smiles',
#  'chuckles',
#  'n give us reason theater beyond wilde wit actors performances',
#  'n give us reason theater beyond wilde wit actors performances',
#  'n give us reason theater beyond wilde wit actors performances',
#  'n give us reason theater beyond wilde wit actors performances',
#  'give us reason theater beyond wilde wit actors performances',
#  'give us',
#  'give',
#  'reason theater beyond wilde wit actors performances',
#  'reason theater beyond wilde wit actors performances',
#  'theater beyond wilde wit actors performances',
#  'theater beyond wilde wit actors performances',
#  'theater',
#  'theater',
#  'theater',
#  'theater',
#  'beyond wilde wit actors performances',
#  'beyond',
#  'wilde wit actors performances',
#  'wilde wit',
#  'wilde wit',
#  'wilde',
#  'wilde',
#  'actors performances',
#  'actors',
#  'actors',
#  'actors',
#  '',
#  'latest vapid actor exercise appropriate structure arthur schnitzler reigen',
#  'latest',
#  'latest',
#  'vapid actor exercise appropriate structure arthur schnitzler reigen',
#  'vapid actor exercise appropriate structure arthur schnitzler reigen',
#  'vapid actor exercise',
#  'vapid',
#  'actor exercise',
#  'actor',
#  'actor',
#  'exercise',
#  'appropriate structure arthur schnitzler reigen',
#  'appropriate structure arthur schnitzler reigen',
#  'appropriate structure',
#  'appropriate',
#  'structure',
#  'structure',
#  'arthur schnitzler reigen',
#  'arthur schnitzler reigen',
#  'arthur schnitzler',
#  'arthur',
#  'schnitzler',
#  'schnitzler',
#  'reigen',
#  'vaudeville show well constructed narrative terms inoffensive actually rather sweet',
#  'vaudeville show well constructed narrative terms inoffensive actually rather sweet',
#  'vaudeville show well constructed narrative',
#  'vaudeville show well constructed narrative',
#  'vaudeville show well constructed narrative',
#  'vaudeville',
#  'vaudeville',
#  'show well constructed narrative',
#  'show',
#  'well constructed narrative',
#  '',
#  'well constructed narrative',
#  'well constructed',
#  'narrative',
#  'terms inoffensive actually rather sweet',
#  'terms',
#  '',
#  'terms',
#  '',
#  'terms',
#  'inoffensive actually rather sweet',
#  'inoffensive actually rather sweet',
#  'inoffensive actually rather sweet',
#  'inoffensive actually',
#  'inoffensive',
#  'inoffensive',
#  'actually',
#  'rather sweet',
#  'rather',
#  'nothing run mill action flick',
#  'run mill action flick',
#  'run mill action',
#  'run mill action',
#  'run mill action',
#  'run mill action',
#  'run mill',
#  'action',
#  'flick',
#  'hampered paralyzed self indulgent script aims poetry ends sounding like satire',
#  'hampered paralyzed self indulgent script aims poetry ends sounding like satire',
#  'hampered paralyzed self indulgent script',
#  'hampered paralyzed self indulgent script',
#  'hampered paralyzed',
#  'hampered',
#  'paralyzed',
#  'paralyzed',
#  'paralyzed',
#  '',
#  'paralyzed',
#  'paralyzed',
#  'self indulgent script',
#  'self indulgent script',
#  'self indulgent script',
#  'self indulgent',
#  'script',
#  '',
#  'aims poetry ends sounding like satire',
#  'aims poetry ends sounding like satire',
#  'aims poetry',
#  'aims poetry',
#  'aims',
#  'poetry',
#  'poetry',
#  'ends sounding like satire',
#  'ends',
#  'ends',
#  '',
#  'sounding like satire',
#  'sounding',
#  'like satire',
#  'satire',
#  'ice age first computer generated feature cartoon feel like movies makes glacial pacing early',
#  'ice age first computer generated feature cartoon feel like movies makes glacial pacing early',
#  'ice age first computer generated feature cartoon feel like movies',
#  'ice age first computer generated feature cartoon feel like movies',
#  'ice age first computer generated feature cartoon feel like movies',
#  'ice age',
#  'ice',
#  'age',
#  'first computer generated feature cartoon feel like movies',
#  'first computer generated feature cartoon feel like movies',
#  'first computer generated feature cartoon',
#  'first computer generated feature cartoon',
#  'first',
#  'computer generated feature cartoon',
#  'computer generated',
#  'feature cartoon',
#  'feature',
#  'cartoon',
#  'feel like movies',
#  'feel like movies',
#  'feel',
#  'like movies',
#  'movies',
#  '',
#  'makes glacial pacing early',
#  'makes glacial pacing early',
#  'makes glacial pacing',
#  'makes',
#  'glacial pacing',
#  'glacial pacing',
#  'glacial pacing',
#  'glacial',
#  'pacing',
#  'early',
#  'early',
#  'little sense going makers serve cliches considerable dash',
#  'little sense going makers serve cliches considerable dash',
#  'little sense going',
#  'little sense going',
#  'little sense going',
#  'little sense going',
#  'little sense going',
#  'little sense',
#  'little',
#  'going',
#  'going',
#  'going',
#  'going',
#  'going',
#  '',
#  'makers serve cliches considerable dash',
#  'makers',
#  'makers',
#  'serve cliches considerable dash',
#  'serve',
#  'serve',
#  'cliches considerable dash',
#  'cliches',
#  'cliches',
#  'considerable dash',
#  'considerable dash',
#  'considerable',
#  'dash',
#  'cattaneo followed runaway success first film full monty something different',
#  'cattaneo',
#  'followed runaway success first film full monty something different',
#  'followed runaway success first film full monty something different',
#  'followed runaway success first film full monty something different',
#  'followed runaway success first film full monty something different',
#  'followed runaway success first film full monty',
#  'followed',
#  'runaway success first film full monty',
#  'runaway success',
#  'runaway success',
#  'runaway',
#  'success',
#  'first film full monty',
#  'first film full monty',
#  'first film full monty',
#  'first film',
#  'first film',
#  'first film',
#  'full monty',
#  'full monty',
#  'full',
#  'monty',
#  'something different',
#  'something different',
#  'different',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies try avoid',
#  '',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies try avoid',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies try avoid',
#  '',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies try avoid',
#  'unnamed easily substitutable forces',
#  'unnamed easily substitutable forces',
#  'unnamed easily substitutable',
#  'unnamed',
#  'easily substitutable',
#  'easily substitutable',
#  'easily',
#  'substitutable',
#  'forces',
#  'serve whatever terror heroes horror movies try avoid',
#  'serve whatever terror heroes horror movies try avoid',
#  'whatever terror heroes horror movies try avoid',
#  'whatever terror heroes horror movies try avoid',
#  'whatever',
#  'terror heroes horror movies try avoid',
#  'terror',
#  'heroes horror movies try avoid',
#  'heroes horror movies',
#  'heroes',
#  'heroes',
#  'horror movies',
#  'horror movies',
#  'horror',
#  'try avoid',
#  ...]

# %%
len(cleaned_phrases)
# Out:
# 156060

# %%
# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",
                             tokenizer = None,
                             preprocessor = None,
                             stop_words = None,
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_feat = vectorizer.fit_transform(cleaned_phrases)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_feat_array = train_feat.toarray()

# %%
train_feat
# Out:
# <156060x5000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 508653 stored elements in Compressed Sparse Row format>

# %%
train_feat_array.shape
# Out:
# (156060, 5000)

# %%
vocab = vectorizer.get_feature_names()
len(vocab)
# Out:
# 5000

# %%
dist = np.sum(train_feat_array, axis=0)

for tag, count in zip(vocab, dist):
  print(count, tag)
# Out:
# Streaming output truncated to the last 5000 lines.
# 130 ability
# 176 able
# 34 absolute
# 82 absolutely
# 82 absorbing
# 75 abstract
# 64 absurd
# 50 absurdity
# 28 abundant
# 56 abuse
# 57 academy
# 46 accent
# 53 accents
# 49 accept
# 57 acceptable
# 32 access
# 67 accessible
# 28 accident
# 65 accomplished
# 24 accomplishments
# 42 account
# 43 accurate
# 28 accurately
# 26 acerbic
# 41 ache
# 29 achieve
# 72 achievement
# 69 achieves
# 41 achingly
# 25 acknowledges
# 156 across
# 241 act
# 179 acted
# 660 acting
# 1170 action
# 41 actions
# 286 actor
# 586 actors
# 159 actress
# 70 actresses
# 84 acts
# 55 actual
# 423 actually
# 38 ad
# 83 adam
# 54 adams
# 160 adaptation
# 35 adapted
# 106 add
# 34 added
# 66 addition
# 49 adds
# 38 adequate
# 26 adequately
# 85 admirable
# 70 admire
# 25 admission
# 56 admit
# 45 admittedly
# 31 adolescence
# 85 adolescent
# 26 adrenaline
# 101 adult
# 194 adults
# 41 advantage
# 245 adventure
# 51 adventures
# 48 adventurous
# 34 advice
# 92 affair
# 24 affected
# 70 affecting
# 104 affection
# 102 affirming
# 26 affleck
# 65 afraid
# 76 african
# 26 afterlife
# 37 afternoon
# 356 age
# 84 aged
# 24 agency
# 33 agent
# 126 ages
# 26 aggrandizing
# 24 aggressive
# 39 aging
# 150 ago
# 24 agonizing
# 38 ah
# 88 ahead
# 40 ai
# 34 aid
# 28 aids
# 33 aim
# 36 aimed
# 35 aimless
# 47 aims
# 179 air
# 40 alabama
# 30 albeit
# 50 album
# 34 alert
# 24 alfred
# 46 alice
# 44 alien
# 46 alienation
# 57 aliens
# 25 alike
# 95 alive
# 43 allegory
# 117 allen
# 58 allow
# 38 allowed
# 122 allows
# 27 alluring
# 619 almost
# 130 alone
# 225 along
# 253 already
# 659 also
# 34 alternate
# 55 alternately
# 54 alternative
# 116 although
# 37 altman
# 44 altogether
# 323 always
# 80 amateurish
# 77 amazing
# 24 amazingly
# 49 ambiguous
# 72 ambition
# 186 ambitious
# 24 ambrose
# 199 america
# 695 american
# 117 americans
# 39 amiable
# 24 amid
# 130 among
# 124 amount
# 60 amounts
# 61 amused
# 332 amusing
# 55 amy
# 35 anachronistic
# 92 analyze
# 40 ancient
# 49 anderson
# 37 angels
# 45 anger
# 46 angle
# 37 angry
# 86 angst
# 43 anguish
# 106 animal
# 34 animals
# 157 animated
# 231 animation
# 27 animatronic
# 33 anime
# 32 annals
# 86 anne
# 95 annoying
# 40 anomie
# 24 anonymous
# 818 another
# 41 answer
# 99 answers
# 42 anthony
# 131 anti
# 35 anticipated
# 45 antics
# 30 antonia
# 59 antwone
# 32 anybody
# 382 anyone
# 470 anything
# 47 anyway
# 39 anywhere
# 118 apart
# 43 aplomb
# 48 appalling
# 90 apparent
# 50 apparently
# 166 appeal
# 172 appealing
# 83 appear
# 83 appears
# 69 appreciate
# 28 appreciated
# 25 appreciation
# 183 approach
# 50 appropriate
# 48 arc
# 58 area
# 44 argentine
# 45 argue
# 26 argument
# 44 arguments
# 27 arms
# 53 arnold
# 449 around
# 27 arrest
# 40 arrive
# 35 arrives
# 483 art
# 32 artful
# 58 artifice
# 85 artificial
# 196 artist
# 124 artistic
# 32 artistry
# 57 artists
# 60 arts
# 39 artsy
# 31 asian
# 51 aside
# 87 ask
# 56 asks
# 28 asleep
# 47 aspect
# 96 aspects
# 33 aspirations
# 24 aspires
# 49 assassin
# 25 assayas
# 28 assembled
# 24 assembly
# 29 associated
# 82 assured
# 60 astonishing
# 41 astonishingly
# 34 astounding
# 24 astute
# 31 athletes
# 41 atlantic
# 115 atmosphere
# 36 atmospheric
# 24 attack
# 40 attal
# 208 attempt
# 23 attempted
# 122 attempts
# 213 attention
# 49 attitude
# 48 attract
# 113 attraction
# 62 attractive
# 39 audacious
# 917 audience
# 268 audiences
# 24 austerity
# 43 austin
# 29 australia
# 23 auteuil
# 27 auteur
# 61 authentic
# 56 authority
# 26 autobiographical
# 31 available
# 31 avant
# 34 avary
# 155 average
# 98 avoid
# 26 awake
# 30 awakening
# 68 award
# 35 awards
# 46 aware
# 32 awareness
# 419 away
# 63 awe
# 148 awful
# 26 awfully
# 69 awkward
# 26 awkwardly
# 38 awkwardness
# 37 baby
# 657 back
# 24 backdrops
# 62 background
# 1305 bad
# 116 badly
# 24 badness
# 27 baffled
# 43 baffling
# 69 bag
# 34 baggage
# 41 baked
# 112 balance
# 42 balanced
# 55 ball
# 44 ballistic
# 43 ballot
# 65 banal
# 105 band
# 28 banderas
# 31 bands
# 69 bang
# 33 bank
# 42 banter
# 44 bar
# 58 barbershop
# 51 bard
# 28 bare
# 188 barely
# 30 barney
# 45 barrel
# 36 barrels
# 55 barry
# 28 barrymore
# 33 bartleby
# 29 bartlett
# 37 base
# 162 based
# 97 basic
# 29 basically
# 44 basis
# 33 basketball
# 165 battle
# 27 battlefield
# 53 beach
# 43 bear
# 97 bears
# 59 beast
# 121 beat
# 316 beautiful
# 223 beautifully
# 219 beauty
# 301 become
# 259 becomes
# 54 becoming
# 28 bed
# 27 beer
# 48 begin
# 72 beginning
# 110 begins
# 117 behavior
# 164 behind
# 44 behold
# 50 beings
# 132 believable
# 276 believe
# 31 believing
# 86 belly
# 53 belongs
# 33 beloved
# 70 belt
# 30 ben
# 88 beneath
# 37 benefit
# 71 benigni
# 27 benjamins
# 32 bent
# 25 besson
# 1123 best
# 29 betrayal
# 26 bette
# 920 better
# 25 betty
# 264 beyond
# 40 bible
# 40 bielinsky
# 895 big
# 71 bigger
# 55 biggest
# 51 bill
# 32 billy
# 28 binoche
# 50 bio
# 35 biography
# 50 biopic
# 34 birot
# 48 birthday
# 452 bit
# 76 bite
# 78 biting
# 87 bits
# 33 bitten
# 87 bitter
# 68 bittersweet
# 41 biz
# 133 bizarre
# 345 black
# 115 blade
# 82 blair
# 46 blame
# 212 bland
# 29 blandness
# 78 blank
# 50 blast
# 27 blatant
# 39 blaxploitation
# 70 bleak
# 69 blend
# 44 blind
# 32 block
# 37 blockbuster
# 25 blockbusters
# 26 blonde
# 142 blood
# 38 blooded
# 42 bloody
# 49 blow
# 67 blown
# 91 blue
# 30 blues
# 28 boasts
# 50 boat
# 50 bodies
# 32 bodily
# 108 body
# 29 bogdanovich
# 26 bogus
# 58 bold
# 29 bollywood
# 30 bombastic
# 114 bond
# 58 bone
# 38 bones
# 28 bonus
# 29 boobs
# 353 book
# 64 books
# 52 boom
# 24 boomer
# 24 boots
# 43 borders
# 88 bore
# 58 bored
# 26 boredom
# 233 boring
# 40 born
# 35 borrows
# 24 boss
# 68 bother
# 94 bottom
# 59 bound
# 53 bourne
# 24 bout
# 55 bow
# 30 bowling
# 73 box
# 266 boy
# 135 boys
# 31 bracing
# 148 brain
# 68 brand
# 28 brash
# 26 bravery
# 31 breadth
# 140 break
# 41 breaking
# 60 breaks
# 36 breakthrough
# 41 breath
# 28 breathe
# 55 breathtaking
# 37 breathtakingly
# 24 breed
# 46 breezy
# 27 brendan
# 42 bride
# 39 bridge
# 42 brief
# 105 bright
# 24 brightly
# 29 brilliance
# 186 brilliant
# 32 brilliantly
# 177 bring
# 53 bringing
# 115 brings
# 41 brisk
# 35 brit
# 161 british
# 74 britney
# 44 brits
# 60 broad
# 43 broadway
# 95 broken
# 43 brooding
# 45 brooklyn
# 67 broomfield
# 32 bros
# 28 brosnan
# 74 brother
# 142 brothers
# 83 brought
# 29 brow
# 111 brown
# 47 bruce
# 54 bruckheimer
# 50 brutal
# 69 brutally
# 49 bucks
# 56 buddy
# 222 budget
# 54 buffs
# 36 bug
# 68 build
# 45 building
# 28 builds
# 48 built
# 29 bull
# 52 bullets
# 108 bullock
# 24 bumbling
# 33 bump
# 84 bunch
# 65 buoyant
# 35 burger
# 44 buried
# 47 burn
# 30 burning
# 72 burns
# 35 burr
# 36 bursts
# 158 business
# 36 busy
# 39 button
# 44 buttons
# 69 buy
# 36 buzz
# 490 ca
# 60 cable
# 48 cage
# 35 caine
# 27 cal
# 31 calculated
# 197 call
# 24 callar
# 162 called
# 34 callow
# 30 calls
# 51 calm
# 56 came
# 318 camera
# 102 camp
# 46 campaign
# 27 camps
# 28 campus
# 26 canadian
# 70 candy
# 36 canned
# 39 cannes
# 29 canny
# 29 canon
# 23 canvas
# 71 capable
# 52 capacity
# 44 caper
# 28 capitalize
# 24 captain
# 49 captivating
# 69 capture
# 120 captures
# 30 capturing
# 172 car
# 28 card
# 447 care
# 201 career
# 51 carefully
# 36 cares
# 33 caricature
# 40 caring
# 41 carmen
# 44 carol
# 43 carpenter
# 65 carried
# 70 carries
# 53 carry
# 27 carrying
# 25 cars
# 144 cartoon
# 33 cartoonish
# 42 cartoons
# 24 caruso
# 33 carved
# 43 carvey
# 198 case
# 24 cash
# 760 cast
# 113 casting
# 37 castro
# 34 casts
# 57 casual
# 68 cat
# 67 catch
# 32 catches
# 27 catching
# 62 category
# 55 catholic
# 52 caught
# 127 cause
# 65 cautionary
# 27 celebrated
# 39 celebrates
# 42 celebration
# 31 celebrity
# 65 cell
# 48 celluloid
# 73 center
# 30 centered
# 125 central
# 163 century
# 34 cerebral
# 175 certain
# 220 certainly
# 52 cgi
# 47 chabrol
# 29 chain
# 33 chair
# 121 challenging
# 27 champion
# 129 chan
# 105 chance
# 49 chances
# 201 change
# 52 changes
# 95 changing
# 110 channel
# 28 chaos
# 61 chaotic
# 25 chaplin
# 1018 character
# 32 characteristic
# 40 characterization
# 52 characterizations
# 28 characterized
# 1882 characters
# 31 charge
# 54 charged
# 74 charisma
# 67 charismatic
# 26 charles
# 30 charlie
# 275 charm
# 48 charmer
# 278 charming
# 44 charmless
# 71 charms
# 96 chase
# 40 chases
# 32 chasing
# 199 cheap
# 48 cheat
# 89 check
# 25 checklist
# 67 cheek
# 33 cheer
# 73 cheese
# 80 cheesy
# 47 chekhov
# 26 chelsea
# 125 chemistry
# 39 chest
# 44 chew
# 43 chicago
# 54 chick
# 50 chief
# 26 chiefly
# 121 child
# 68 childhood
# 39 childish
# 45 childlike
# 376 children
# 25 chill
# 38 chiller
# 100 chilling
# 55 chills
# 63 chilly
# 26 chimps
# 58 china
# 84 chinese
# 44 cho
# 27 chocolate
# 53 choice
# 75 choices
# 71 choose
# 34 chooses
# 59 choppy
# 47 chops
# 33 chord
# 32 chosen
# 41 chou
# 85 chris
# 60 christian
# 92 christmas
# 29 christopher
# 31 chronicles
# 32 chuckle
# 41 chuckles
# 45 church
# 35 cia
# 593 cinema
# 380 cinematic
# 114 cinematography
# 31 cipher
# 34 circuit
# 34 circumstances
# 32 circus
# 223 city
# 24 civic
# 34 clad
# 25 clancy
# 98 clarity
# 29 clash
# 24 clashing
# 248 class
# 303 classic
# 44 classical
# 42 classics
# 40 clause
# 44 claustrophobic
# 26 clayburgh
# 61 clean
# 25 cleaner
# 168 clear
# 114 clearly
# 29 cletis
# 376 clever
# 67 cleverly
# 51 cleverness
# 80 cliche
# 87 cliched
# 208 cliches
# 25 clients
# 31 cliff
# 48 climactic
# 24 climate
# 30 climax
# 24 clinic
# 25 clinical
# 33 clockstoppers
# 43 clooney
# 212 close
# 26 closed
# 44 closely
# 41 closer
# 49 closing
# 54 clothes
# 28 clown
# 70 cloying
# 27 club
# 25 clubs
# 46 clue
# 32 clueless
# 40 clumsily
# 63 clumsy
# 161 co
# 40 cobbled
# 36 code
# 31 coen
# 46 coffee
# 53 coherent
# 52 cohesive
# 269 cold
# 24 collaboration
# 23 collateral
# 71 collection
# 23 collective
# 172 college
# 32 collision
# 76 color
# 28 colored
# 136 colorful
# 42 colors
# 37 com
# 30 coma
# 35 combat
# 77 combination
# 45 combined
# 28 combines
# 545 come
# 59 comedian
# 106 comedic
# 218 comedies
# 1813 comedy
# 513 comes
# 56 comfort
# 76 comfortable
# 478 comic
# 24 comically
# 30 comics
# 327 coming
# 90 commentary
# 106 commercial
# 29 commitment
# 52 committed
# 104 common
# 60 communal
# 120 community
# 159 company
# 24 compare
# 24 compared
# 55 comparison
# 75 compassion
# 469 compelling
# 25 compensate
# 52 competent
# 26 competition
# 39 complaint
# 116 complete
# 225 completely
# 240 complex
# 26 complexities
# 54 complexity
# 100 complicated
# 60 complications
# 29 composed
# 37 composition
# 24 comprehend
# 31 compromise
# 133 computer
# 75 con
# 27 conceit
# 37 conceits
# 40 conceived
# 232 concept
# 49 concern
# 95 concerned
# 42 concert
# 32 concession
# 144 conclusion
# 26 condensed
# 94 condition
# 35 conditioning
# 28 conditions
# 40 conduct
# 28 confidence
# 42 confident
# 25 confined
# 120 conflict
# 29 conflicted
# 26 confront
# 39 confused
# 80 confusing
# 97 connect
# 28 connected
# 65 connection
# 38 conquer
# 109 conscious
# 46 consciously
# 55 consciousness
# 57 consequences
# 52 conservative
# 51 consider
# 142 considerable
# 65 considered
# 32 considering
# 24 consigned
# 36 consistent
# 84 consistently
# 39 consolation
# 27 conspicuous
# 52 conspiracy
# 59 constant
# 42 constantly
# 48 construct
# 101 constructed
# 27 construction
# 24 constructs
# 30 consuming
# 24 contact
# 27 contains
# 26 contemplation
# 162 contemporary
# 64 content
# 37 contest
# 63 context
# 42 continues
# 31 continuity
# 36 contradictory
# 26 contribution
# 64 contrivances
# 218 contrived
# 75 control
# 37 controversy
# 55 convenient
# 128 conventional
# 36 conventions
# 32 conversation
# 40 conversations
# 42 convey
# 26 conveying
# 96 conviction
# 26 convictions
# 48 convince
# 47 convinced
# 179 convincing
# 41 convoluted
# 210 cool
# 34 cooper
# 80 cop
# 28 coppola
# 45 cops
# 48 copy
# 159 core
# 74 corner
# 53 corny
# 30 correctness
# 64 cost
# 32 costly
# 32 costner
# 44 costume
# 42 costumes
# 969 could
# 73 count
# 27 counter
# 36 counterparts
# 31 countless
# 168 country
# 166 couple
# 102 courage
# 112 course
# 55 cover
# 29 covers
# 38 crack
# 28 crackle
# 33 craft
# 144 crafted
# 26 craig
# 26 crammed
# 31 crane
# 62 crap
# 63 crass
# 37 craven
# 24 craziness
# 147 crazy
# 149 create
# 93 created
# 104 creates
# 77 creating
# 71 creation
# 34 creations
# 183 creative
# 71 creativity
# 44 creature
# 24 creatures
# 54 credibility
# 76 credible
# 115 credit
# 97 credits
# 24 creepiness
# 205 creepy
# 260 crime
# 83 crimes
# 44 criminal
# 27 crippled
# 56 crisis
# 73 crisp
# 56 critical
# 45 critics
# 34 critique
# 26 crocodile
# 110 cross
# 31 crosses
# 27 crossover
# 25 crossroads
# 161 crowd
# 51 crucial
# 69 crude
# 27 crudity
# 41 crudup
# 77 cruel
# 72 crush
# 43 cry
# 29 cuban
# 28 cube
# 82 cult
# 194 cultural
# 380 culture
# 55 cultures
# 25 cup
# 25 cure
# 74 curiosity
# 54 curious
# 42 curiously
# 28 curling
# 65 current
# 214 cut
# 158 cute
# 37 cuteness
# 34 cutesy
# 46 cuts
# 78 cutting
# 23 cyber
# 73 cynical
# 37 cynicism
# 30 dad
# 51 dahmer
# 62 daily
# 84 damage
# 61 damaged
# 26 damme
# 58 damn
# 132 damned
# 34 damon
# 32 dana
# 80 dance
# 82 dancing
# 42 danger
# 76 dangerous
# 26 daniel
# 45 dare
# 37 dares
# 71 daring
# 497 dark
# 73 darker
# 35 darkly
# 31 darkness
# 25 darling
# 24 dashing
# 27 dass
# 180 date
# 66 daughter
# 25 daughters
# 164 david
# 73 davis
# 46 dawns
# 71 dawson
# 418 day
# 23 daydreams
# 226 days
# 43 daytime
# 26 dazzle
# 80 dazzling
# 254 de
# 257 dead
# 86 deadly
# 41 deadpan
# 131 deal
# 24 dealers
# 75 dealing
# 24 deals
# 38 dean
# 297 death
# 28 deaths
# 29 debate
# 26 debt
# 283 debut
# 46 decade
# 116 decades
# 48 decency
# 172 decent
# 36 deceptions
# 55 deceptively
# 24 decide
# 40 decided
# 48 decidedly
# 36 decision
# 64 dedication
# 238 deep
# 105 deeper
# 27 deepest
# 251 deeply
# 35 defeated
# 34 defies
# 23 defines
# 117 definitely
# 25 definition
# 43 definitive
# 69 deft
# 57 deftly
# 83 degree
# 35 deja
# 37 deliberate
# 30 deliberately
# 107 delicate
# 35 delicately
# 37 delicious
# 108 delight
# 140 delightful
# 60 delightfully
# 58 delights
# 80 deliver
# 69 delivered
# 55 delivering
# 140 delivers
# 121 delivery
# 30 demand
# 42 demanding
# 65 demands
# 42 demented
# 26 demme
# 51 demographic
# 41 demons
# 29 demonstrate
# 46 demonstrates
# 44 denial
# 26 denied
# 42 deniro
# 29 dentist
# 35 denying
# 55 department
# 30 departure
# 26 dependent
# 62 depiction
# 42 deprecating
# 26 depressed
# 118 depressing
# 162 depth
# 117 derivative
# 25 derived
# 30 derrida
# 49 describe
# 67 deserve
# 43 deserved
# 125 deserves
# 60 design
# 77 designed
# 95 desire
# 27 desired
# 76 despair
# 68 desperate
# 53 desperately
# 63 desperation
# 273 despite
# 48 destination
# 57 destruction
# 32 destructive
# 28 detached
# 83 detail
# 79 detailed
# 108 details
# 60 determination
# 84 determined
# 33 deuces
# 82 devastating
# 37 develop
# 76 developed
# 81 development
# 32 develops
# 53 devices
# 93 devoid
# 24 devolves
# 575 dialogue
# 31 diaries
# 25 diary
# 46 dickens
# 26 dickensian
# 29 didactic
# 102 die
# 42 diesel
# 52 difference
# 31 differences
# 247 different
# 214 difficult
# 90 digital
# 66 dignity
# 33 dilemma
# 28 dim
# 38 dime
# 29 dimension
# 98 dimensional
# 30 dinner
# 82 direct
# 252 directed
# 85 directing
# 410 direction
# 31 directions
# 30 directly
# 1338 director
# 85 directorial
# 130 directors
# 28 directs
# 105 dirty
# 25 disappoint
# 39 disappointed
# 60 disappointing
# 36 disappointingly
# 86 disaster
# 39 disbelief
# 25 discerned
# 29 discourse
# 33 discover
# 24 discovering
# 100 discovery
# 33 discussion
# 33 disease
# 57 disguise
# 26 disguised
# 32 disgust
# 32 disgusting
# 62 dish
# 25 dishonest
# 29 disintegrating
# 24 disjointed
# 38 dismissed
# 190 disney
# 38 disparate
# 50 display
# 26 displays
# 43 disposable
# 24 disquieting
# 30 disregard
# 69 distance
# 41 distant
# 39 distasteful
# 32 distinct
# 46 distinctive
# 37 distinctly
# 34 distinguished
# 29 distract
# 59 disturbing
# 31 diverse
# 42 diversion
# 95 diverting
# 51 divine
# 96 document
# 47 documentaries
# 533 documentary
# 200 dog
# 57 dogs
# 24 dollar
# 55 domestic
# 372 done
# 43 dong
# 27 donovan
# 36 door
# 25 dopey
# 39 dose
# 49 doses
# 39 dots
# 85 double
# 116 doubt
# 31 dover
# 52 downbeat
# 84 downright
# 39 doze
# 45 dozen
# 28 dozens
# 125 drag
# 25 dragged
# 50 dragon
# 35 dragonfly
# 33 dragons
# 38 drags
# 977 drama
# 52 dramas
# 333 dramatic
# 62 dramatically
# 43 draw
# 46 drawing
# 25 drawings
# 81 drawn
# 44 draws
# 25 dreadful
# 145 dream
# 124 dreams
# 88 dreary
# 40 drenched
# 30 dress
# 36 dressed
# 37 drew
# 51 drink
# 92 drive
# 42 driven
# 39 driver
# 25 drives
# 37 droll
# 55 drop
# 30 drown
# 93 drug
# 63 drugs
# 32 drunk
# 30 drunken
# 186 dry
# 46 dubbed
# 31 dubious
# 30 duck
# 29 dud
# 30 dude
# 50 due
# 28 duke
# 386 dull
# 40 dullest
# 27 dumas
# 227 dumb
# 42 dumbed
# 24 duration
# 35 dust
# 26 dustin
# 27 dutiful
# 43 duty
# 29 duvall
# 34 dv
# 108 dvd
# 61 dying
# 48 dynamic
# 39 dynamics
# 70 dysfunctional
# 39 eager
# 38 ear
# 32 earlier
# 103 early
# 37 earn
# 27 earned
# 194 earnest
# 55 earnestness
# 36 ears
# 110 earth
# 30 ease
# 52 easier
# 219 easily
# 29 east
# 26 eastern
# 43 eastwood
# 336 easy
# 52 eat
# 26 eating
# 24 eats
# 65 eccentric
# 25 ecks
# 39 economic
# 25 economical
# 35 ed
# 46 eddie
# 160 edge
# 38 edges
# 43 edgy
# 35 edit
# 57 edited
# 117 editing
# 42 edition
# 37 education
# 31 educational
# 39 eerie
# 89 effect
# 126 effective
# 36 effectively
# 353 effects
# 303 effort
# 38 effortlessly
# 94 efforts
# 49 ego
# 26 egoyan
# 61 eight
# 289 either
# 60 elaborate
# 28 electric
# 29 elegance
# 64 elegant
# 38 elegantly
# 57 element
# 216 elements
# 34 elevate
# 37 elizabeth
# 27 ellen
# 58 eloquent
# 265 else
# 25 elsewhere
# 37 elusive
# 105 em
# 35 embarrassed
# 51 embarrassment
# 38 embrace
# 40 embraces
# 23 embracing
# 47 emerge
# 63 emerges
# 23 emerging
# 102 emotion
# 615 emotional
# 210 emotionally
# 199 emotions
# 102 empathy
# 24 emperor
# 38 emphasis
# 39 emphasizes
# 42 empire
# 42 empowerment
# 48 emptiness
# 108 empty
# 52 encounter
# 28 encounters
# 47 encouraging
# 655 end
# 126 endearing
# 61 endeavor
# 58 ended
# 252 ending
# 83 endless
# 57 endlessly
# 195 ends
# 33 endurance
# 56 endure
# 31 enduring
# 90 energetic
# 327 energy
# 41 engage
# 67 engaged
# 315 engaging
# 84 english
# 148 engrossing
# 38 enigma
# 40 enigmatic
# 267 enjoy
# 336 enjoyable
# 27 enjoyably
# 59 enjoyed
# 32 enjoyment
# 40 enormous
# 34 enormously
# 1253 enough
# 137 ensemble
# 48 enter
# 49 enterprise
# 64 entertain
# 35 entertained
# 613 entertaining
# 25 entertainingly
# 429 entertainment
# 34 enthralling
# 58 enthusiasm
# 47 enthusiastic
# 158 entire
# 197 entirely
# 38 entry
# 31 enveloping
# 26 environmental
# 163 epic
# 156 episode
# 39 episodes
# 46 equal
# 134 equally
# 33 equilibrium
# 66 equivalent
# 47 er
# 152 era
# 47 eric
# 47 erotic
# 29 erratic
# 25 errors
# 100 escape
# 60 escapism
# 326 especially
# 49 esque
# 68 essence
# 106 essentially
# 30 established
# 25 establishes
# 30 esteem
# 49 esther
# 25 et
# 30 etc
# 38 ethereal
# 36 ethnic
# 34 european
# 30 evade
# 54 evans
# 48 evelyn
# 1624 even
# 47 evening
# 77 event
# 200 events
# 40 eventual
# 72 eventually
# 829 ever
# 24 everlasting
# 859 every
# 24 everybody
# 48 everyday
# 285 everyone
# 319 everything
# 33 evidence
# 36 evident
# 151 evil
# 73 evocative
# 39 evoke
# 24 evokes
# 23 evolved
# 37 exact
# 149 exactly
# 33 exaggerated
# 157 examination
# 23 examine
# 30 examines
# 68 example
# 36 exceedingly
# 154 excellent
# 24 excels
# 118 except
# 33 exception
# 46 exceptional
# 31 exceptionally
# 71 excess
# 33 excesses
# 24 exchange
# 25 excited
# 101 excitement
# 119 exciting
# 25 excruciating
# 29 excruciatingly
# 81 excuse
# 55 executed
# 150 execution
# 288 exercise
# 29 exhausted
# 30 exhausting
# 70 exhilarating
# 31 exist
# 49 existed
# 54 existence
# 52 existential
# 27 existing
# 29 exists
# 43 exit
# 75 exotic
# 176 expect
# 43 expectation
# 58 expectations
# 86 expected
# 30 expecting
# 52 expense
# 385 experience
# 34 experienced
# 100 experiences
# 33 expert
# 25 explode
# 33 exploit
# 76 exploitation
# 52 exploitative
# 33 exploiting
# 27 exploitive
# 103 exploration
# 68 explore
# 29 explores
# 44 exploring
# 39 explosion
# 46 explosions
# 46 exposition
# 49 express
# 41 expression
# 31 expressive
# 79 exquisite
# 63 extended
# 30 extensive
# 49 extent
# 24 exterior
# 58 extra
# 27 extraordinarily
# 89 extraordinary
# 31 extravagant
# 44 extravaganza
# 140 extreme
# 114 extremely
# 24 exuberance
# 213 eye
# 89 eyed
# 25 eyelids
# 244 eyes
# 45 fable
# 47 fabric
# 396 face
# 86 faced
# 36 faces
# 25 facet
# 37 facing
# 202 fact
# 39 factor
# 31 factory
# 26 fade
# 36 fail
# 30 failing
# 200 fails
# 100 failure
# 70 fair
# 215 fairly
# 71 fairy
# 120 faith
# 68 faithful
# 70 fake
# 110 fall
# 25 fallen
# 25 falling
# 151 falls
# 85 false
# 43 familial
# 426 familiar
# 40 familiarity
# 97 families
# 725 family
# 61 famous
# 114 fan
# 58 fanciful
# 61 fancy
# 412 fans
# 57 fantasies
# 89 fantastic
# 214 fantasy
# 684 far
# 86 farce
# 32 farcical
# 108 fare
# 41 farrelly
# 44 farts
# 381 fascinating
# 86 fashion
# 199 fashioned
# 167 fast
# 87 faster
# 83 fat
# 95 fatal
# 77 fate
# 95 father
# 44 fathers
# 117 favor
# 48 favorite
# 30 favors
# 96 fear
# 42 feardotcom
# 108 fears
# 39 feast
# 55 feat
# 39 feathers
# 414 feature
# 70 features
# 39 featuring
# 40 feces
# 881 feel
# 300 feeling
# 32 feelings
# 477 feels
# 47 feet
# 45 fellow
# 163 felt
# 169 female
# 43 feminist
# 25 fence
# 24 ferocity
# 24 fervently
# 31 fest
# 130 festival
# 25 fetched
# 33 fewer
# 176 fi
# 151 fiction
# 51 field
# 41 fiennes
# 55 fierce
# 25 fiery
# 42 fifteen
# 86 fight
# 64 fighting
# 63 fights
# 126 figure
# 27 figured
# 61 figures
# 74 fill
# 112 filled
# 69 filling
# 36 fills
# 6733 film
# 85 filmed
# 34 filming
# 257 filmmaker
# 319 filmmakers
# 303 filmmaking
# 979 films
# 208 final
# 77 finale
# 173 finally
# 572 find
# 97 finding
# 110 finds
# 261 fine
# 39 finely
# 29 finest
# 28 fingers
# 87 finish
# 202 fire
# 45 firing
# 992 first
# 94 fish
# 82 fisher
# 38 fisted
# 132 fit
# 34 fits
# 24 fitting
# 141 five
# 31 fix
# 28 fizz
# 27 flaccid
# 81 flair
# 48 flamboyant
# 35 flash
# 30 flashes
# 70 flashy
# 256 flat
# 30 flavor
# 23 flaw
# 170 flawed
# 155 flaws
# 35 fleeting
# 48 flesh
# 397 flick
# 176 flicks
# 47 flimsy
# 32 flip
# 23 flirts
# 25 floating
# 36 floor
# 48 flop
# 28 flourishes
# 60 flow
# 26 fluent
# 61 fluff
# 31 fluid
# 62 fly
# 62 focus
# 35 focused
# 56 folk
# 84 folks
# 84 follow
# 48 followed
# 51 following
# 50 follows
# 74 food
# 32 fool
# 27 foolish
# 105 footage
# 133 force
# 122 forced
# 28 forceful
# 31 forcefully
# 48 forces
# 53 ford
# 127 foreign
# 133 forget
# 116 forgettable
# 77 forgive
# 23 forgiven
# 76 forgotten
# 143 form
# 24 formal
# 63 format
# 54 former
# 219 formula
# 113 formulaic
# 50 forth
# 26 forward
# 28 foster
# 63 foul
# 199 found
# 221 four
# 65 fourth
# 40 fragile
# 41 frailty
# 148 frame
# 44 france
# 130 franchise
# 103 frank
# 33 frantic
# 57 freaks
# 170 free
# 37 freedom
# 44 freeman
# 312 french
# 27 frequent
# 92 frequently
# 290 fresh
# 49 freshness
# 69 frida
# 77 friday
# 63 friend
# 65 friendly
# 78 friends
# 134 friendship
# 81 frightening
# 26 frills
# 28 fringes
# 101 front
# 34 frontal
# 37 frozen
# 96 frustrating
# 34 frustratingly
# 65 frustration
# 25 fu
# 28 fulfill
# 618 full
# 164 fully
# 759 fun
# 25 function
# 130 funnier
# 104 funniest
# 1583 funny
# 182 future
# 43 fuzzy
# 75 gag
# 246 gags
# 223 game
# 115 games
# 79 gang
# 58 gangs
# 109 gangster
# 33 gantz
# 43 garbage
# 32 garde
# 27 gasp
# 46 gave
# 159 gay
# 24 gaza
# 28 geeks
# 37 gel
# 49 gem
# 76 gender
# 107 general
# 94 generally
# 58 generate
# 62 generated
# 25 generates
# 26 generating
# 114 generation
# 28 generations
# 118 generic
# 26 generosity
# 48 generous
# 55 genial
# 33 genius
# 401 genre
# 44 genres
# 30 genteel
# 188 gentle
# 42 gently
# 157 genuine
# 92 genuinely
# 142 george
# 25 gere
# 26 geriatric
# 52 german
# 810 get
# 418 gets
# 202 getting
# 66 ghetto
# 70 ghost
# 24 ghosts
# 109 giant
# 26 gibson
# 34 giddy
# 37 gift
# 72 gifted
# 45 gifts
# 38 giggles
# 342 girl
# 39 girlfriend
# 157 girls
# 506 give
# 203 given
# 368 gives
# 116 giving
# 35 glaring
# 76 glass
# 25 glasses
# 32 gleaned
# 23 glib
# 92 glimpse
# 34 glimpses
# 42 glorified
# 36 glorious
# 38 gloriously
# 101 glory
# 29 gloss
# 38 glossy
# 593 go
# 38 goal
# 24 goals
# 89 god
# 48 godard
# 24 godfrey
# 310 goes
# 534 going
# 24 golden
# 192 gone
# 26 gong
# 32 goo
# 2261 good
# 45 goodfellas
# 43 goods
# 24 goodwill
# 24 goofball
# 143 goofy
# 43 goose
# 35 gore
# 183 gorgeous
# 36 gorgeously
# 33 gory
# 32 gosford
# 33 gosling
# 200 got
# 63 grab
# 144 grace
# 38 graceful
# 32 graceless
# 103 grade
# 74 gradually
# 107 grand
# 68 grandeur
# 26 grandiosity
# 26 grandson
# 131 grant
# 90 graphic
# 44 grasp
# 34 grating
# 40 gratuitous
# 44 gravity
# 864 great
# 37 greater
# 132 greatest
# 29 greatness
# 66 greek
# 122 green
# 41 greene
# 47 grew
# 43 grey
# 101 grief
# 33 grim
# 94 gripping
# 31 grisly
# 60 gritty
# 25 groan
# 162 gross
# 88 ground
# 87 group
# 40 groups
# 93 grow
# 120 growing
# 74 grown
# 64 grows
# 29 growth
# 26 guaranteed
# 76 guess
# 50 guessing
# 25 guffaw
# 24 guide
# 54 guilt
# 122 guilty
# 25 guitar
# 52 gun
# 107 guns
# 49 gut
# 35 guts
# 199 guy
# 195 guys
# 53 gyllenhaal
# 42 hack
# 118 hackneyed
# 102 hair
# 30 hal
# 551 half
# 65 halfway
# 33 hall
# 44 hallmark
# 56 halloween
# 52 ham
# 28 hammy
# 209 hand
# 88 handed
# 63 handful
# 29 handle
# 53 handled
# 94 hands
# 64 handsome
# 34 haneke
# 30 hang
# 45 hanks
# 55 hannibal
# 131 happen
# 78 happened
# 66 happening
# 82 happens
# 26 happily
# 67 happiness
# 140 happy
# 24 harbor
# 718 hard
# 41 harder
# 108 hardly
# 64 harmless
# 55 harris
# 68 harrowing
# 76 harry
# 36 harsh
# 43 hartley
# 48 harvard
# 57 hastily
# 41 hat
# 115 hate
# 25 hates
# 41 hatred
# 27 haunted
# 85 haunting
# 31 hawaiian
# 24 hawk
# 32 haynes
# 308 head
# 24 headed
# 55 heads
# 41 heady
# 46 heal
# 25 health
# 56 hear
# 94 heard
# 27 hearst
# 714 heart
# 30 heartache
# 55 heartbreaking
# 108 hearted
# 99 heartfelt
# 89 hearts
# 69 heartwarming
# 39 heat
# 113 heaven
# 36 heavily
# 211 heavy
# 38 hedonistic
# 24 hefty
# 30 heights
# 33 heist
# 57 held
# 145 hell
# 211 help
# 24 helped
# 47 helps
# 42 henry
# 207 hero
# 45 heroes
# 24 heroic
# 55 heroine
# 61 herzog
# 33 hewitt
# 51 hey
# 31 hidden
# 50 hide
# 35 hideously
# 512 high
# 32 higher
# 53 highest
# 147 highly
# 25 highs
# 24 highway
# 226 hilarious
# 33 hilarity
# 48 hill
# 39 hint
# 175 hip
# 32 hippie
# 223 historical
# 33 historically
# 484 history
# 189 hit
# 26 hitchcock
# 31 hitchcockian
# 29 hitler
# 83 hits
# 55 hitting
# 30 ho
# 95 hoffman
# 36 hokum
# 160 hold
# 101 holds
# 50 hole
# 93 holes
# 124 holiday
# 31 hollow
# 53 holly
# 789 hollywood
# 45 holm
# 72 holocaust
# 89 homage
# 275 home
# 25 homes
# 227 honest
# 56 honestly
# 45 honesty
# 66 hong
# 28 honor
# 38 hook
# 30 hoot
# 98 hop
# 121 hope
# 36 hoped
# 88 hopeful
# 32 hopeless
# 51 hoping
# 60 hopkins
# 81 horrible
# 25 horribly
# 78 horrifying
# 359 horror
# 25 horrors
# 24 hospital
# 24 host
# 143 hot
# 41 hotel
# 457 hour
# 318 hours
# 233 house
# 25 houses
# 59 howard
# 98 however
# 142 huge
# 53 hugely
# 49 hugh
# 750 human
# 37 humane
# 146 humanity
# 23 humanly
# 37 humans
# 25 humdrum
# 856 humor
# 33 humorless
# 87 humorous
# 94 humour
# 27 hundred
# 40 hungry
# 47 hunter
# 34 huppert
# 29 hurley
# 37 hurt
# 92 husband
# 27 huston
# 42 hybrid
# 55 hype
# 25 hypertime
# 34 hypnotic
# 120 ice
# 30 icon
# 27 iconoclastic
# 363 idea
# 25 ideal
# 31 idealism
# 25 idealistic
# 278 ideas
# 119 identity
# 45 idiosyncratic
# 27 idiotic
# 25 idiots
# 27 ignore
# 38 ignored
# 196 ii
# 24 ilk
# 124 ill
# 27 illness
# 25 illuminating
# 34 illustrates
# 81 image
# 80 imagery
# 235 images
# 27 imaginable
# 232 imagination
# 84 imaginative
# 155 imagine
# 119 imax
# 60 imitation
# 24 immature
# 56 immediate
# 29 immediately
# 38 immensely
# 149 impact
# 41 impeccable
# 29 impenetrable
# 27 impersonal
# 57 implausible
# 31 import
# 65 importance
# 206 important
# 251 impossible
# 34 impressed
# 74 impression
# 34 impressions
# 141 impressive
# 26 impressively
# 56 improbable
# 40 improve
# 25 improvement
# 43 improvised
# 28 impulse
# 27 impulses
# 54 inane
# 29 inappropriate
# 23 incarnation
# 38 incessant
# 39 incident
# 45 incisive
# 43 inclination
# 34 includes
# 85 including
# 38 incoherence
# 53 incoherent
# 46 incompetent
# 34 incomprehensible
# 36 incongruous
# 38 inconsequential
# 39 inconsistent
# 76 increasingly
# 25 incredible
# 82 incredibly
# 68 indeed
# 42 independent
# 91 indian
# 45 indians
# 25 indication
# 24 indictment
# 137 indie
# 30 indifference
# 40 individual
# 24 induced
# 31 indulgence
# 97 indulgent
# 128 industry
# 74 inept
# 32 inescapable
# 87 inevitable
# 37 inevitably
# 25 inexperienced
# 49 inexplicable
# 24 inexplicably
# 46 infidelity
# 24 infinitely
# 41 influence
# 38 influenced
# 37 infomercial
# 35 informative
# 24 informed
# 39 ingenious
# 25 ingredients
# 55 inhabit
# 44 inherent
# 35 initial
# 32 injuries
# 109 inner
# 76 innocence
# 54 innocent
# 29 innovation
# 29 innovative
# 29 innuendo
# 51 inoffensive
# 29 inquiry
# 36 insane
# 45 insanely
# 24 insecure
# 241 inside
# 161 insight
# 98 insightful
# 68 insights
# 41 insipid
# 29 insistent
# 36 insomnia
# 68 inspiration
# 59 inspirational
# 48 inspire
# 164 inspired
# 35 inspires
# 111 inspiring
# 35 installment
# 36 instance
# 56 instantly
# 298 instead
# 48 instincts
# 29 institution
# 30 insult
# 48 insulting
# 26 insultingly
# 47 insurance
# 60 integrity
# 26 intellect
# 94 intellectual
# 293 intelligence
# 286 intelligent
# 134 intended
# 120 intense
# 26 intensely
# 92 intensity
# 38 intent
# 27 intentionally
# 41 intentioned
# 102 intentions
# 28 inter
# 27 interaction
# 344 interest
# 135 interested
# 649 interesting
# 50 intermittently
# 53 international
# 26 internet
# 36 interpretation
# 34 interview
# 26 interviews
# 51 intimacy
# 123 intimate
# 38 intolerable
# 58 intoxicating
# 58 intricate
# 129 intrigue
# 223 intriguing
# 23 introduce
# 34 introduction
# 23 introspective
# 25 invaluable
# 49 invention
# 136 inventive
# 37 inventiveness
# 33 inviting
# 27 involve
# 118 involved
# 97 involving
# 24 iran
# 84 iranian
# 66 irish
# 57 ironic
# 34 ironies
# 53 irony
# 36 irrelevant
# 41 irresistible
# 31 irresponsible
# 83 irritating
# 25 irwin
# 27 island
# 34 isolation
# 29 israeli
# 55 issue
# 196 issues
# 104 italian
# 82 jack
# 27 jackass
# 49 jackie
# 103 jackson
# 38 jaded
# 31 jagger
# 43 jaglom
# 114 james
# 32 jane
# 32 janice
# 47 japan
# 84 japanese
# 57 jar
# 37 jarring
# 60 jason
# 40 jaw
# 27 jazzy
# 50 jealousy
# 44 jean
# 28 jell
# 39 jennifer
# 36 jerking
# 50 jerry
# 32 jet
# 48 jewish
# 56 jim
# 48 joan
# 175 job
# 48 joe
# 41 joel
# 307 john
# 130 joke
# 257 jokes
# 34 jolie
# 33 jolt
# 23 jolts
# 39 jonah
# 86 jones
# 37 jordan
# 25 journalism
# 162 journey
# 96 joy
# 27 joyless
# 53 joyous
# 32 jr
# 36 judd
# 30 juicy
# 31 julia
# 31 juliette
# 41 jumbo
# 29 jump
# 43 junior
# 47 junk
# 142 justice
# 72 justify
# 56 juvenile
# 50 kahlo
# 33 kapur
# 23 kathy
# 68 kaufman
# 24 keen
# 466 keep
# 50 keeping
# 155 keeps
# 31 kennedy
# 28 kenneth
# 96 kevin
# 130 key
# 39 kick
# 48 kicking
# 192 kid
# 67 kiddie
# 31 kidman
# 516 kids
# 36 kieslowski
# 65 kill
# 69 killed
# 136 killer
# 26 killing
# 24 kilter
# 683 kind
# 40 kinda
# 24 kinds
# 119 king
# 46 kiss
# 91 kissinger
# 29 kitchen
# 27 kitten
# 45 kline
# 28 knack
# 56 knew
# 397 know
# 88 knowing
# 105 knowledge
# 84 known
# 167 knows
# 72 kong
# 40 korea
# 41 korean
# 32 kosashvili
# 44 kung
# 31 kwan
# 25 labor
# 54 labored
# 24 labyrinthine
# 24 laced
# 258 lack
# 126 lacking
# 54 lackluster
# 196 lacks
# 78 lady
# 35 laid
# 25 laissez
# 103 lame
# 42 lampoon
# 105 land
# 76 landscape
# 34 landscapes
# 38 lane
# 32 lanes
# 87 language
# 42 languorous
# 25 lapses
# 177 large
# 88 largely
# 89 larger
# 488 last
# 26 lasting
# 137 late
# 51 later
# 173 latest
# 34 latin
# 48 latter
# 30 laudable
# 280 laugh
# 57 laughable
# 39 laughed
# 74 laughing
# 380 laughs
# 75 laughter
# 31 lavish
# 76 lawrence
# 28 laws
# 43 layered
# 59 layers
# 84 lazy
# 178 lead
# 65 leaden
# 41 leading
# 96 leads
# 42 league
# 28 leaky
# 61 learn
# 39 learned
# 24 learning
# 460 least
# 28 leather
# 272 leave
# 142 leaves
# 79 leaving
# 81 lee
# 252 left
# 52 legacy
# 48 legal
# 36 legendary
# 31 legged
# 42 lends
# 146 length
# 24 leon
# 712 less
# 60 lesser
# 99 lesson
# 40 lessons
# 145 let
# 88 lets
# 25 letter
# 53 letting
# 329 level
# 85 levels
# 31 lewis
# 34 liberal
# 37 liberating
# 31 liberation
# 28 liberties
# 25 librarian
# 45 lie
# 44 lies
# 1718 life
# 40 lifeless
# 48 lifestyle
# 57 lifetime
# 32 lift
# 27 lifts
# 368 light
# 25 lighthearted
# 39 lighting
# 29 lights
# 46 lightweight
# 53 likable
# 3190 like
# 104 liked
# 265 likely
# 26 lilia
# 30 lilo
# 26 limitations
# 76 limited
# 32 limits
# 29 limp
# 304 line
# 25 liners
# 104 lines
# 52 lingering
# 26 lingers
# 36 lion
# 39 lip
# 26 lips
# 136 list
# 38 listen
# 64 listless
# 45 lit
# 43 literal
# 52 literally
# 79 literary
# 38 literate
# 1605 little
# 309 live
# 113 lived
# 40 lively
# 378 lives
# 156 living
# 28 load
# 29 loaded
# 42 loads
# 38 locales
# 62 locations
# 44 lock
# 26 lodging
# 53 lofty
# 27 log
# 72 logic
# 28 lola
# 26 london
# 48 loneliness
# 32 lonely
# 907 long
# 93 longer
# 42 longest
# 46 longing
# 897 look
# 67 looked
# 416 looking
# 226 looks
# 71 loose
# 37 loosely
# 52 lopez
# 39 lord
# 29 lose
# 26 losers
# 80 loses
# 58 losing
# 133 loss
# 195 lost
# 560 lot
# 117 lots
# 190 loud
# 67 lousy
# 24 lovable
# 1324 love
# 63 loved
# 122 lovely
# 54 lovers
# 57 loves
# 70 loving
# 401 low
# 44 lower
# 23 loyal
# 33 loyalty
# 2098 lrb
# 49 luck
# 39 lucky
# 38 lucy
# 94 ludicrous
# 38 lump
# 39 lunacy
# 44 lunatic
# 38 lunch
# 36 lurid
# 58 lush
# 44 lust
# 35 lynch
# 28 lyne
# 67 lyrical
# 104 machine
# 35 machismo
# 45 mad
# 1198 made
# 73 madness
# 48 madonna
# 149 magic
# 43 magical
# 41 magnificent
# 122 main
# 49 mainly
# 112 mainstream
# 55 maintain
# 26 maintaining
# 40 maintains
# 174 major
# 1414 make
# 78 makers
# 1019 makes
# 30 makeup
# 523 making
# 30 malaise
# 117 male
# 40 malkovich
# 26 mamet
# 884 man
# 54 manage
# 28 managed
# 287 manages
# 71 manhattan
# 29 manhood
# 26 manipulation
# 127 manipulative
# 50 mann
# 153 manner
# 44 mannered
# 28 mannerisms
# 30 manners
# 41 manufactured
# 1094 many
# 23 map
# 27 marching
# 51 marginal
# 32 marina
# 30 marine
# 117 mark
# 61 market
# 95 marks
# 30 marquis
# 65 marriage
# 27 mars
# 27 mart
# 49 martha
# 57 martial
# 119 martin
# 32 marvel
# 56 marvelous
# 29 marvelously
# 58 mary
# 34 massive
# 143 master
# 58 masterful
# 28 masterfully
# 131 masterpiece
# 114 match
# 610 material
# 75 matinee
# 375 matter
# 58 matters
# 47 matthew
# 69 mature
# 80 maudlin
# 30 max
# 986 may
# 135 maybe
# 90 mayhem
# 31 maze
# 24 mcculloch
# 201 mean
# 90 meandering
# 160 meaning
# 68 meaningful
# 36 meaningless
# 130 means
# 50 meant
# 55 measure
# 37 measured
# 47 meat
# 34 mechanical
# 53 media
# 49 medical
# 153 mediocre
# 28 mediocrity
# 128 meditation
# 25 meditative
# 32 medium
# 25 meet
# 69 meets
# 24 megaplex
# 26 mel
# 44 melancholy
# 285 melodrama
# 120 melodramatic
# 32 melt
# 34 member
# 117 members
# 215 memorable
# 71 memories
# 138 memory
# 357 men
# 45 menace
# 42 mental
# 54 mentally
# 82 mention
# 35 merchant
# 87 mere
# 142 merely
# 65 merit
# 35 merits
# 26 mermaid
# 76 mesmerizing
# 186 mess
# 266 message
# 74 messages
# 25 messiness
# 26 messy
# 27 metal
# 73 metaphor
# 39 metaphorical
# 27 metaphors
# 24 metropolis
# 29 metropolitan
# 37 mexican
# 30 miami
# 24 mib
# 241 michael
# 33 michel
# 61 mid
# 329 middle
# 64 midnight
# 24 midway
# 698 might
# 42 mike
# 83 mild
# 143 mildly
# 77 mile
# 35 milk
# 70 mill
# 46 miller
# 55 million
# 336 mind
# 120 minded
# 117 mindless
# 62 minds
# 26 minimal
# 45 minimalist
# 33 minimum
# 110 minor
# 345 minute
# 811 minutes
# 24 mira
# 37 miracle
# 40 miramax
# 25 mirren
# 43 misery
# 29 misfire
# 28 misguided
# 31 misogyny
# 89 miss
# 80 missed
# 31 misses
# 94 missing
# 64 mistake
# 24 mistress
# 110 mix
# 106 mixed
# 64 mixture
# 29 miyazaki
# 37 mo
# 23 moderately
# 367 modern
# 88 modest
# 27 modestly
# 25 modesty
# 28 molly
# 206 moment
# 667 moments
# 48 momentum
# 159 money
# 24 monotonous
# 33 monsoon
# 188 monster
# 55 monsters
# 40 monstrous
# 26 months
# 101 monty
# 196 mood
# 36 moods
# 39 moody
# 64 moore
# 239 moral
# 45 morality
# 41 morally
# 59 morning
# 25 morvern
# 198 mostly
# 162 mother
# 37 mothers
# 38 mothman
# 123 motion
# 30 motions
# 47 motivated
# 38 motivations
# 26 mountain
# 77 mouth
# 27 mouthed
# 103 move
# 32 moved
# 48 movement
# 63 movements
# 64 moves
# 6241 movie
# 85 moviegoers
# 36 moviegoing
# 69 moviemaking
# 1345 movies
# 403 moving
# 302 mr
# 128 ms
# 37 mtv
# 1872 much
# 30 muddle
# 35 muddled
# 33 mugging
# 36 multi
# 29 multiplex
# 27 mumbo
# 34 mundane
# 134 murder
# 61 murky
# 104 murphy
# 44 mushy
# 574 music
# 85 musical
# 30 musicians
# 227 must
# 31 muster
# 28 musty
# 27 muted
# 41 mysteries
# 62 mysterious
# 228 mystery
# 27 myth
# 38 mythic
# 25 na
# 27 naipaul
# 29 nair
# 39 naked
# 165 name
# 40 named
# 30 names
# 25 napoleon
# 28 narcissism
# 27 narration
# 370 narrative
# 32 narratively
# 36 narrator
# 26 narrow
# 97 nasty
# 62 nation
# 105 national
# 27 native
# 109 natural
# 43 naturalistic
# 30 naturally
# 231 nature
# 71 natured
# 28 naughty
# 115 near
# 384 nearly
# 62 neat
# 47 necessarily
# 82 necessary
# 35 neck
# 406 need
# 100 needed
# 24 needlessly
# 159 needs
# 23 needy
# 27 negotiate
# 35 neighborhood
# 40 neil
# 189 neither
# 30 nelson
# 36 neo
# 31 nerds
# 62 nerve
# 27 nerves
# 30 nervous
# 27 nervy
# 23 net
# 1114 never
# 52 nevertheless
# 1305 new
# 43 newcomer
# 98 news
# 315 next
# 165 nice
# 98 nicely
# 76 niche
# 52 nicholas
# 45 nicholson
# 29 nickleby
# 34 nifty
# 194 night
# 68 nightmare
# 25 nights
# 47 nijinsky
# 34 nine
# 106 niro
# 43 noble
# 34 nobody
# 109 noir
# 54 noise
# 61 nomination
# 132 non
# 209 none
# 28 nonexistent
# 26 nonjudgmental
# 67 nonsense
# 27 nonsensical
# 27 normally
# 25 north
# 46 nose
# 72 nostalgia
# 23 nostalgic
# 33 notable
# 55 notch
# 65 note
# 69 notes
# 724 nothing
# 80 notice
# 69 notion
# 53 notorious
# 39 notwithstanding
# 204 novel
# 68 nowhere
# 43 nuance
# 51 nuanced
# 28 nuances
# 33 nudity
# 127 number
# 116 numbers
# 26 numbing
# 41 numbingly
# 24 nyc
# 27 object
# 48 objective
# 26 objectivity
# 42 obligatory
# 62 obnoxious
# 29 obscure
# 44 observant
# 39 observation
# 77 observations
# 27 obsessed
# 69 obsession
# 31 obsessions
# 33 obsessive
# 48 obstacles
# 313 obvious
# 54 obviously
# 44 occasional
# 184 occasionally
# 38 ocean
# 183 odd
# 24 oddest
# 95 oddly
# 78 odds
# 61 ode
# 38 odyssey
# 29 oedekerk
# 65 offbeat
# 30 offend
# 100 offensive
# 150 offer
# 71 offering
# 278 offers
# 113 office
# 704 often
# 57 oh
# 1180 old
# 112 older
# 3784 one
# 174 ones
# 92 onscreen
# 102 onto
# 36 opaque
# 141 open
# 25 opened
# 82 opening
# 38 openness
# 37 opens
# 293 opera
# 25 operative
# 32 opinion
# 29 opportunities
# 114 opportunity
# 34 optimism
# 29 optimistic
# 25 ordeal
# 68 order
# 99 ordinary
# 26 organic
# 71 oriented
# 648 original
# 87 originality
# 202 oscar
# 156 others
# 238 otherwise
# 26 otherworldly
# 28 ought
# 42 outcome
# 43 outer
# 43 outing
# 38 outrage
# 83 outrageous
# 76 outside
# 25 outsiders
# 60 outstanding
# 37 outtakes
# 152 overall
# 34 overblown
# 119 overcome
# 24 overexposed
# 48 overlong
# 91 overly
# 34 overrun
# 27 overtly
# 52 overwhelming
# 68 overwrought
# 30 owe
# 28 owes
# 174 pace
# 122 paced
# 141 pacing
# 83 pack
# 26 package
# 85 packed
# 29 page
# 78 paid
# 94 pain
# 160 painful
# 97 painfully
# 54 paint
# 28 painting
# 33 paints
# 67 pair
# 57 pale
# 46 palma
# 27 palpable
# 31 panache
# 50 pandering
# 38 pantheon
# 47 pants
# 106 paper
# 24 papin
# 26 par
# 45 parable
# 53 parade
# 46 paradiso
# 38 paranoia
# 30 paranoid
# 44 parent
# 192 parents
# 24 paris
# 90 park
# 58 parker
# 23 parking
# 65 parody
# 401 part
# 37 participants
# 120 particular
# 235 particularly
# 47 partly
# 31 partner
# 69 parts
# 136 party
# 73 pass
# 39 passable
# 28 passed
# 25 passer
# 30 passes
# 219 passion
# 53 passionate
# 25 passions
# 305 past
# 34 pastiche
# 76 pat
# 32 patch
# 79 path
# 74 pathetic
# 56 pathology
# 59 pathos
# 56 patience
# 32 patient
# 72 paul
# 27 pauline
# 30 paxton
# 141 pay
# 27 paying
# 33 payne
# 72 payoff
# 39 pays
# 28 peak
# 24 pearl
# 57 peculiar
# 35 pedestrian
# 47 pedigree
# 40 peek
# 27 penetrating
# 1073 people
# 30 perceptive
# 310 perfect
# 190 perfectly
# 25 perform
# 710 performance
# 765 performances
# 27 performed
# 107 performers
# 25 performing
# 89 perhaps
# 24 peril
# 215 period
# 108 person
# 101 persona
# 255 personal
# 49 personalities
# 103 personality
# 136 perspective
# 31 pertinent
# 34 pervasive
# 55 perverse
# 32 pessimistic
# 113 peter
# 31 pg
# 31 phenomenal
# 31 philip
# 104 philosophical
# 46 philosophy
# 40 phone
# 63 phones
# 57 phony
# 24 photo
# 42 photographed
# 37 photography
# 26 phrase
# 48 physical
# 23 physique
# 49 pianist
# 37 piano
# 80 pic
# 26 piccoli
# 66 pick
# 36 picked
# 603 picture
# 199 pictures
# 62 pie
# 412 piece
# 144 pieces
# 28 piffle
# 72 pile
# 32 pilot
# 29 pink
# 55 pinocchio
# 29 pit
# 64 pitch
# 38 pitched
# 35 pitfalls
# 60 pity
# 416 place
# 27 placed
# 150 places
# 143 plain
# 35 plane
# 74 planet
# 255 play
# 77 played
# 39 player
# 66 players
# 109 playful
# 190 playing
# 249 plays
# 26 playwright
# 103 pleasant
# 92 please
# 41 pleaser
# 76 pleasing
# 37 pleasurable
# 237 pleasure
# 62 pleasures
# 190 plenty
# 40 plight
# 63 plodding
# 985 plot
# 24 plotless
# 26 plotline
# 45 plots
# 63 plotted
# 78 plotting
# 27 plus
# 51 plympton
# 71 poem
# 25 poet
# 109 poetic
# 118 poetry
# 25 poets
# 67 poignancy
# 88 poignant
# 489 point
# 43 pointed
# 112 pointless
# 139 points
# 45 pokemon
# 36 pokes
# 63 polanski
# 94 police
# 33 policy
# 41 polished
# 314 political
# 44 politically
# 121 politics
# 27 pompeo
# 59 ponder
# 38 ponderous
# 42 pool
# 139 poor
# 123 poorly
# 232 pop
# 135 popcorn
# 28 popping
# 36 popular
# 28 popularity
# 56 porn
# 25 portions
# 299 portrait
# 53 portray
# 58 portrayal
# 60 portrays
# 67 positive
# 38 positively
# 31 possess
# 39 possibilities
# 28 possibility
# 205 possible
# 99 possibly
# 137 post
# 38 postcard
# 28 poster
# 25 posturing
# 57 potent
# 159 potential
# 93 potentially
# 58 poverty
# 47 pow
# 345 power
# 321 powerful
# 24 powerfully
# 86 powers
# 28 practically
# 27 practice
# 34 praise
# 24 praises
# 34 pratfalls
# 58 pre
# 78 preachy
# 71 precious
# 55 precisely
# 36 precision
# 76 predecessor
# 39 predecessors
# 29 predicament
# 26 predict
# 38 predictability
# 313 predictable
# 54 predictably
# 24 preemptive
# 31 prefer
# 353 premise
# 25 preordained
# 32 prep
# 53 preposterous
# 85 presence
# 97 present
# 52 presentation
# 40 presented
# 72 presents
# 25 preservation
# 40 press
# 56 pretends
# 55 pretension
# 51 pretensions
# 170 pretentious
# 415 pretty
# 27 prevent
# 182 previous
# 105 price
# 29 pride
# 38 primarily
# 38 primary
# 30 prime
# 27 prism
# 56 prison
# 68 private
# 25 privileged
# 46 pro
# 295 probably
# 27 probe
# 27 probing
# 175 problem
# 58 problematic
# 149 problems
# 29 procedural
# 82 proceedings
# 167 process
# 29 procession
# 45 produce
# 114 produced
# 56 producer
# 45 producers
# 120 product
# 217 production
# 32 productions
# 27 profane
# 60 professional
# 36 professionals
# 31 proficient
# 46 profile
# 78 profound
# 26 profoundly
# 31 program
# 270 project
# 37 projects
# 134 promise
# 34 promised
# 47 promises
# 87 promising
# 35 proof
# 59 propaganda
# 44 proper
# 39 properly
# 31 prophecies
# 37 proportions
# 35 prose
# 36 prospect
# 114 protagonist
# 45 protagonists
# 55 proud
# 82 prove
# 193 proves
# 92 provide
# 84 provides
# 39 providing
# 128 provocative
# 81 provoking
# 30 pryor
# 63 pseudo
# 36 psyche
# 37 psycho
# 190 psychological
# 37 psychologically
# 62 psychology
# 109 public
# 27 puerile
# 93 pull
# 33 pulled
# 51 pulling
# 75 pulls
# 52 pulp
# 34 pulpy
# 34 pulse
# 55 pun
# 83 punch
# 33 punching
# 33 pungent
# 38 punk
# 24 puppet
# 141 pure
# 30 purely
# 142 purpose
# 24 purposes
# 43 push
# 24 pushes
# 243 put
# 117 puts
# 55 putting
# 24 puzzle
# 30 puzzling
# 24 qualify
# 27 qualities
# 189 quality
# 130 queen
# 37 queens
# 36 quentin
# 69 quest
# 108 question
# 24 questionable
# 135 questions
# 114 quick
# 85 quickly
# 153 quiet
# 27 quieter
# 107 quietly
# 66 quirks
# 280 quirky
# 554 quite
# 68 race
# 28 races
# 62 racial
# 29 racism
# 33 racist
# 41 radar
# 50 radical
# 26 rage
# 34 rah
# 25 rain
# 37 raise
# 38 raised
# 28 raises
# 25 raising
# 40 ralph
# 25 ram
# 28 rambling
# 31 ramsay
# 31 randall
# 51 random
# 54 range
# 43 rank
# 45 ranks
# 40 rap
# 24 rape
# 38 rapid
# 240 rare
# 122 rarely
# 25 rarity
# 126 rate
# 641 rather
# 52 rating
# 28 ratliff
# 36 rattling
# 24 raucous
# 38 raunch
# 28 raunchy
# 44 ravishing
# 105 raw
# 26 raymond
# 81 reach
# 31 reaches
# 32 reaching
# 38 reaction
# 133 read
# 88 reading
# 51 ready
# 871 real
# 112 realism
# 95 realistic
# 23 realities
# 261 reality
# 71 realize
# 85 realized
# 27 realizing
# 888 really
# 27 realm
# 281 reason
# 66 reasonably
# 40 reasons
# 27 rebellion
# 32 recall
# 39 receive
# 28 receiving
# 283 recent
# 36 recipe
# 25 recite
# 27 recklessness
# 25 recognizable
# 29 recognize
# 115 recommend
# 34 recommendation
# 34 recommended
# 87 record
# 37 recording
# 26 records
# 37 recovery
# 58 recycled
# 137 red
# 27 redeeming
# 47 redemption
# 31 reduced
# 25 redundancy
# 32 redundant
# 26 reefs
# 74 reel
# 61 references
# 44 reflection
# 89 refreshing
# 70 refreshingly
# 50 refugees
# 57 refusal
# 28 refuses
# 24 regard
# 31 regarding
# 24 regardless
# 44 reggio
# 26 region
# 48 regret
# 38 rehash
# 65 reign
# 24 related
# 168 relationship
# 187 relationships
# 30 relative
# 89 relatively
# 130 release
# 86 released
# 35 relentless
# 63 relentlessly
# 48 relevant
# 29 reliable
# 55 relief
# 62 relies
# 29 religious
# 46 reluctant
# 39 rely
# 69 remain
# 188 remains
# 150 remake
# 190 remarkable
# 92 remarkably
# 114 remember
# 56 remembered
# 44 remembering
# 32 remind
# 34 reminded
# 23 reminder
# 25 reminding
# 45 reminds
# 40 reminiscent
# 37 remote
# 34 remotely
# 85 rendered
# 78 reno
# 33 renowned
# 63 rent
# 69 rental
# 23 repeatedly
# 30 repetition
# 79 repetitive
# 48 replaced
# 29 replete
# 57 report
# 24 represented
# 68 represents
# 39 repressed
# 39 reputation
# 44 require
# 51 required
# 23 requires
# 25 requisite
# 29 reruns
# 43 rescue
# 31 research
# 32 resemble
# 27 resembles
# 29 reserved
# 66 resist
# 42 resolutely
# 26 resolution
# 67 resonance
# 67 resonant
# 29 resonate
# 51 resourceful
# 103 respect
# 66 respectable
# 28 responsibility
# 39 responsible
# 148 rest
# 35 restroom
# 63 result
# 78 results
# 25 retaliation
# 84 retread
# 34 retro
# 64 return
# 48 returns
# 37 reunion
# 32 reveal
# 32 revealed
# 101 revealing
# 116 reveals
# 38 revelation
# 57 revelations
# 59 revelatory
# 93 revenge
# 26 review
# 26 reviews
# 96 revolution
# 60 rewarding
# 48 rewards
# 71 rhythm
# 81 rhythms
# 48 rice
# 263 rich
# 57 richard
# 53 richer
# 44 richly
# 24 richness
# 42 ridden
# 232 ride
# 83 ridiculous
# 30 riffs
# 634 right
# 29 rigid
# 26 rigor
# 60 ring
# 39 rings
# 25 ringu
# 33 riot
# 100 rip
# 30 ripe
# 62 rise
# 55 rises
# 49 rising
# 27 risk
# 24 risks
# 59 ritchie
# 25 rival
# 31 river
# 96 riveting
# 205 road
# 61 rob
# 171 robert
# 39 roberto
# 37 roberts
# 36 robin
# 33 robinson
# 223 rock
# 33 rocket
# 45 rocky
# 71 roger
# 27 rogue
# 46 rohmer
# 251 role
# 66 roles
# 67 roll
# 30 rollerball
# 32 rollicking
# 55 rolling
# 54 roman
# 306 romance
# 32 romances
# 545 romantic
# 40 romp
# 25 ron
# 196 room
# 39 root
# 59 rooting
# 66 roots
# 51 rose
# 51 rote
# 27 rouge
# 56 rough
# 122 routine
# 28 routines
# 31 row
# 58 rowdy
# 2438 rrb
# 47 rude
# 26 rug
# 28 ruined
# 24 rules
# 286 run
# 34 runner
# 236 running
# 106 runs
# 81 rush
# 33 rushed
# 73 russian
# 97 ryan
# 57 saccharine
# 39 sacrifice
# 26 sacrificing
# 235 sad
# 56 sade
# 52 sadly
# 85 sadness
# 56 safe
# 52 saga
# 111 said
# 85 sake
# 33 salt
# 26 salton
# 28 san
# 25 sanctimony
# 67 sand
# 126 sandler
# 41 sandra
# 67 sane
# 61 santa
# 104 sappy
# 42 sara
# 29 sarah
# 58 sarandon
# 32 sardonic
# 176 satire
# 26 satiric
# 70 satirical
# 82 satisfied
# 28 satisfies
# 231 satisfying
# 88 saturday
# 28 savage
# 100 save
# 32 saved
# 59 saving
# 58 savvy
# 160 saw
# 422 say
# 73 saying
# 43 says
# 63 scale
# 28 scarcely
# 25 scare
# 28 scares
# 194 scary
# 53 scattered
# 64 scenario
# 243 scene
# 50 scenery
# 576 scenes
# 25 scenic
# 26 schaeffer
# 36 schemes
# 29 schizophrenia
# 32 schmaltz
# 25 schmaltzy
# 39 schmidt
# 71 schneider
# 296 school
# 53 schwarzenegger
# 175 sci
# 127 science
# 45 scooby
# 34 scope
# 118 score
# 60 scores
# 26 scorn
# 24 scorpion
# 68 scorsese
# 29 scott
# 62 scratch
# 44 scratching
# 42 scream
# 59 screaming
# 826 screen
# 40 screening
# 354 screenplay
# 35 screens
# 91 screenwriter
# 56 screenwriters
# 84 screenwriting
# 39 screwball
# 664 script
# 40 scripts
# 32 scrooge
# 28 scruffy
# 30 scrutiny
# 111 sea
# 94 seagal
# 27 seams
# 46 search
# 51 searching
# 34 seas
# 110 season
# 165 seat
# 25 seated
# 46 seats
# 224 second
# 57 seconds
# 59 secret
# 31 secretary
# 68 secrets
# 45 section
# 985 see
# 224 seeing
# 68 seek
# 54 seeking
# 40 seeks
# 474 seem
# 26 seemed
# 55 seeming
# 41 seemingly
# 502 seems
# 659 seen
# 57 sees
# 31 segment
# 32 seinfeld
# 24 seldahl
# 27 selection
# 1027 self
# 76 sell
# 24 selling
# 49 semi
# 57 send
# 42 sensational
# 888 sense
# 31 senses
# 44 sensibilities
# 43 sensibility
# 130 sensitive
# 37 sensitivity
# 51 sensual
# 24 sensuality
# 46 sentence
# 66 sentiment
# 181 sentimental
# 109 sentimentality
# 24 sentiments
# 41 separate
# 213 sequel
# 113 sequels
# 113 sequence
# 227 sequences
# 54 serial
# 363 series
# 304 serious
# 113 seriously
# 24 sermon
# 49 serve
# 114 served
# 72 serves
# 95 service
# 43 serviceable
# 24 serving
# 24 sessions
# 390 set
# 121 sets
# 120 setting
# 27 settled
# 38 settles
# 30 setup
# 62 seven
# 25 sever
# 162 several
# 43 severe
# 29 severely
# 257 sex
# 148 sexual
# 25 sexuality
# 24 sexually
# 119 sexy
# 27 shadow
# 65 shadows
# 26 shadowy
# 31 shadyac
# 26 shaggy
# 87 shake
# 24 shaken
# 24 shakes
# 58 shakespeare
# 28 shakespearean
# 128 shallow
# 87 shame
# 41 shameless
# 42 shamelessly
# 49 shanghai
# 45 shape
# 55 shaped
# 55 shapeless
# 138 share
# 24 shared
# 141 sharp
# 94 sheer
# 69 shelf
# 43 shenanigans
# 25 shepard
# 46 shifting
# 35 shine
# 26 shines
# 48 shining
# 32 ship
# 95 shock
# 81 shocking
# 33 shockingly
# 57 shocks
# 26 shoddy
# 32 shoe
# 141 shoot
# 75 shooting
# 28 shootings
# 27 shop
# 376 short
# 246 shot
# 142 shots
# 48 shoulders
# 32 shout
# 468 show
# 31 showcase
# 25 showcases
# 45 shower
# 25 showgirls
# 63 showing
# 219 shows
# 64 showtime
# 25 shred
# 29 shrek
# 38 shrewd
# 36 shrill
# 40 shtick
# 57 shyamalan
# 114 sick
# 30 sickening
# 292 side
# 25 sided
# 105 sides
# 24 siegel
# 107 sight
# 74 sign
# 29 significance
# 55 significant
# 92 signs
# 44 silence
# 61 silent
# 60 silliness
# 361 silly
# 60 silver
# 64 similar
# 51 similarly
# 36 simone
# 223 simple
# 40 simplicity
# 108 simplistic
# 329 simply
# 69 simultaneously
# 28 sin
# 348 since
# 134 sincere
# 37 sincerity
# 27 sing
# 31 singer
# 48 singing
# 212 single
# 32 sinister
# 71 sink
# 33 sister
# 38 sisterhood
# 43 sisters
# 176 sit
# 95 sitcom
# 33 sits
# 111 sitting
# 163 situation
# 155 situations
# 44 six
# 27 sixth
# 33 size
# 33 sized
# 26 skateboard
# 62 sketch
# 57 sketchy
# 24 skewed
# 26 skies
# 117 skill
# 34 skills
# 161 skin
# 46 skip
# 43 slack
# 45 slackers
# 68 slap
# 34 slapdash
# 26 slapping
# 130 slapstick
# 27 slasher
# 60 sleep
# 24 sleeper
# 23 sleeping
# 30 sleepless
# 30 sleeve
# 80 slice
# 31 slick
# 23 slide
# 131 slight
# 32 slightest
# 136 slightly
# 53 slip
# 39 slippery
# 37 slo
# 105 sloppy
# 250 slow
# 51 slowly
# 36 sluggish
# 44 sly
# 31 smack
# 330 small
# 344 smart
# 64 smarter
# 27 smartest
# 37 smartly
# 38 smash
# 117 smile
# 31 smiles
# 32 smiling
# 26 smirk
# 26 smith
# 32 smoking
# 27 smoochy
# 30 smoother
# 25 smoothly
# 59 smug
# 33 snake
# 30 snappy
# 24 snatch
# 30 sneaks
# 50 snipes
# 96 snow
# 37 soaked
# 222 soap
# 35 sober
# 46 sobering
# 25 soccer
# 310 social
# 125 society
# 32 sociology
# 90 soderbergh
# 45 soft
# 36 soggy
# 67 soldiers
# 25 solemn
# 276 solid
# 34 solidly
# 85 solondz
# 30 solutions
# 74 somber
# 42 somebody
# 68 somehow
# 143 someone
# 1160 something
# 434 sometimes
# 169 somewhat
# 113 somewhere
# 103 son
# 83 song
# 88 songs
# 29 sonny
# 24 sons
# 103 soon
# 25 sophie
# 132 sophisticated
# 61 sophomoric
# 33 sordid
# 25 sorority
# 34 sorry
# 271 sort
# 36 sorvino
# 163 soul
# 48 soulful
# 38 soulless
# 59 souls
# 119 sound
# 110 sounds
# 117 soundtrack
# 72 sour
# 98 source
# 28 sources
# 126 south
# 63 southern
# 117 space
# 31 spaces
# 39 spader
# 24 span
# 64 spare
# 91 spark
# 52 sparkling
# 28 sparse
# 53 speak
# 84 speaking
# 45 speaks
# 65 spears
# 512 special
# 52 specific
# 39 specifically
# 29 specimen
# 99 spectacle
# 58 spectacular
# 25 spectacularly
# 27 speculation
# 62 spell
# 75 spend
# 91 spent
# 26 spice
# 77 spider
# 151 spielberg
# 45 spike
# 51 spin
# 44 spinning
# 316 spirit
# 105 spirited
# 56 spirits
# 131 spiritual
# 59 spite
# 26 splash
# 55 splendid
# 26 splendor
# 30 split
# 29 splitting
# 25 spontaneity
# 55 spoof
# 81 spooky
# 26 sporadic
# 38 sport
# 133 sports
# 47 spot
# 33 spotlight
# 33 spots
# 59 spring
# 192 spy
# 28 squad
# 28 squanders
# 27 square
# 36 squarely
# 49 squeeze
# 60 st
# 31 stabbing
# 89 stage
# 53 staged
# 25 stages
# 27 staggeringly
# 109 stale
# 285 stand
# 126 standard
# 77 standards
# 49 stands
# 536 star
# 27 stark
# 100 starring
# 142 stars
# 162 start
# 72 started
# 30 starting
# 60 startling
# 138 starts
# 75 state
# 35 stately
# 45 static
# 50 station
# 40 status
# 95 stay
# 49 stays
# 30 steal
# 39 stealing
# 30 steers
# 136 step
# 33 stephen
# 71 stereotypes
# 46 stereotypical
# 40 steve
# 130 steven
# 33 stick
# 35 sticks
# 29 sticky
# 35 stiff
# 772 still
# 50 stilted
# 41 sting
# 29 stinker
# 62 stirring
# 27 stitch
# 99 stock
# 110 stomach
# 34 stone
# 85 stop
# 39 stops
# 76 store
# 311 stories
# 2539 story
# 119 storyline
# 30 storylines
# 253 storytelling
# 212 straight
# 76 straightforward
# 66 strain
# 220 strange
# 100 strangely
# 28 strangeness
# 96 street
# 110 strength
# 24 strengths
# 34 stretched
# 38 stretches
# 26 strict
# 48 strictly
# 56 strike
# 47 strikes
# 104 striking
# 78 string
# 27 strip
# 25 stroke
# 326 strong
# 31 stronger
# 39 strongly
# 33 struck
# 84 structure
# 48 structured
# 104 struggle
# 27 struggled
# 47 struggling
# 29 strung
# 37 stuart
# 70 stuck
# 45 student
# 114 studio
# 33 studios
# 342 study
# 276 stuff
# 92 stunning
# 67 stunt
# 62 stunts
# 165 stupid
# 32 stupidity
# 535 style
# 24 styled
# 33 styles
# 152 stylish
# 41 stylistic
# 45 stylized
# 60 sub
# 24 subcontinent
# 45 subculture
# 505 subject
# 99 subjects
# 29 sublime
# 25 submarine
# 31 subplots
# 132 substance
# 64 substantial
# 30 substitute
# 32 subtext
# 42 subtitles
# 134 subtle
# 24 subtlest
# 74 subtlety
# 55 subtly
# 45 suburban
# 50 subversive
# 42 succeed
# 78 succeeds
# 173 success
# 143 successful
# 29 succumb
# 30 succumbs
# 52 suck
# 28 sucked
# 44 sucker
# 52 sudden
# 30 suddenly
# 24 sudsy
# 29 suffer
# 32 suffered
# 92 suffering
# 104 suffers
# 55 sugar
# 31 sugarman
# 32 suggest
# 31 suggestion
# 43 suggests
# 52 suit
# 47 suited
# 29 suits
# 83 sum
# 362 summer
# 42 sumptuous
# 44 sun
# 38 sundance
# 87 super
# 83 superb
# 95 superficial
# 96 superior
# 24 superman
# 35 supernatural
# 26 supply
# 39 support
# 77 supporting
# 196 supposed
# 33 supremely
# 245 sure
# 53 surely
# 105 surface
# 29 surfing
# 141 surprise
# 36 surprised
# 136 surprises
# 173 surprising
# 303 surprisingly
# 46 surreal
# 25 surround
# 53 surrounding
# 41 survival
# 46 survive
# 38 susan
# 34 suspend
# 276 suspense
# 68 suspenseful
# 153 sustain
# 31 sustained
# 25 sustains
# 55 swallow
# 28 sway
# 25 swear
# 24 sweat
# 72 sweeping
# 430 sweet
# 40 sweetly
# 56 sweetness
# 30 swept
# 37 swim
# 24 swimming
# 31 swinging
# 27 swings
# 25 swooping
# 25 sword
# 51 sympathetic
# 72 sympathy
# 44 system
# 60 table
# 32 tackling
# 25 tadpole
# 574 take
# 149 taken
# 441 takes
# 164 taking
# 570 tale
# 227 talent
# 179 talented
# 87 talents
# 44 tales
# 64 talk
# 110 talking
# 41 talky
# 28 tambor
# 25 tank
# 57 tap
# 72 tarantino
# 157 target
# 30 targeted
# 26 tart
# 35 task
# 185 taste
# 26 tasteful
# 53 tasty
# 32 tattered
# 30 taut
# 35 tawdry
# 48 taylor
# 31 taymor
# 29 tea
# 27 teach
# 54 teacher
# 30 teachers
# 96 team
# 115 tear
# 29 tearing
# 25 tearjerker
# 65 tears
# 45 tech
# 56 technical
# 36 technically
# 31 technique
# 67 technology
# 128 tedious
# 31 tediously
# 33 teeming
# 275 teen
# 87 teenage
# 83 teenagers
# 59 teens
# 68 teeth
# 33 telegraphed
# 151 television
# 215 tell
# 131 telling
# 96 tells
# 31 temple
# 28 tempting
# 41 ten
# 26 tenacious
# 83 tender
# 29 tends
# 25 tenor
# 37 tense
# 155 tension
# 28 tensions
# 38 tepid
# 61 term
# 125 terms
# 117 terrible
# 44 terribly
# 188 terrific
# 75 terrifying
# 83 territory
# 35 terror
# 42 terrorism
# 39 terrorist
# 53 test
# 54 testament
# 29 testimony
# 28 testosterone
# 59 text
# 51 textbook
# 32 texture
# 195 th
# 102 thanks
# 25 thanksgiving
# 371 theater
# 85 theaters
# 95 theatre
# 35 theatres
# 75 theatrical
# 58 thematic
# 26 thematically
# 100 theme
# 29 themed
# 177 themes
# 41 theories
# 37 theory
# 41 therapy
# 67 thick
# 240 thin
# 522 thing
# 687 things
# 437 think
# 181 thinking
# 84 thinks
# 25 thinly
# 124 third
# 24 thirteen
# 39 thirty
# 53 thomas
# 157 thoroughly
# 487 though
# 302 thought
# 177 thoughtful
# 34 thousand
# 69 thousands
# 33 threadbare
# 43 threat
# 24 threatened
# 472 three
# 66 thrill
# 613 thriller
# 45 thrillers
# 29 thrilling
# 104 thrills
# 154 throughout
# 41 throw
# 23 throwback
# 49 throwing
# 39 thrown
# 58 throws
# 47 thumbs
# 35 tick
# 77 ticket
# 26 tied
# 42 ties
# 44 tight
# 1919 time
# 24 timed
# 40 timeless
# 71 timely
# 553 times
# 25 timid
# 55 timing
# 25 tiniest
# 26 tinseltown
# 84 tiny
# 192 tired
# 87 tiresome
# 341 title
# 27 titled
# 49 titles
# 37 titular
# 25 titus
# 35 toback
# 156 today
# 41 todd
# 444 together
# 54 toilet
# 193 told
# 30 tolerance
# 135 tom
# 38 tomorrow
# 308 tone
# 32 tones
# 73 tongue
# 52 took
# 42 tool
# 26 tooth
# 241 top
# 49 topic
# 28 topical
# 27 topless
# 53 torn
# 27 torture
# 69 tortured
# 30 tosca
# 29 toss
# 27 tosses
# 70 total
# 87 totally
# 171 touch
# 44 touched
# 53 touches
# 194 touching
# 87 tough
# 33 tour
# 28 tout
# 101 toward
# 28 towards
# 46 town
# 26 trade
# 79 trademark
# 77 tradition
# 86 traditional
# 24 traditionally
# 43 traditions
# 38 traffic
# 59 tragedies
# 256 tragedy
# 154 tragic
# 33 tragically
# 56 trailer
# 32 train
# 36 transcend
# 37 transcends
# 34 transformation
# 39 transforms
# 34 translation
# 29 trap
# 37 trapped
# 59 trappings
# 83 trash
# 41 trashy
# 55 travel
# 37 traveler
# 85 treasure
# 89 treat
# 129 treatment
# 37 treats
# 42 trees
# 65 trek
# 33 tremendous
# 30 trenchant
# 57 triangle
# 107 tribute
# 89 trick
# 52 tricks
# 49 tried
# 200 tries
# 59 trifle
# 27 trilogy
# 170 trip
# 26 tripe
# 55 trite
# 98 triumph
# 25 triumphant
# 24 triumphs
# 31 tropes
# 139 trouble
# 38 truck
# 430 true
# 275 truly
# 28 trust
# 185 truth
# 33 truthful
# 189 try
# 353 trying
# 38 tsai
# 29 tub
# 26 tuck
# 30 tug
# 30 turf
# 283 turn
# 124 turned
# 97 turning
# 248 turns
# 28 tuxedo
# 384 tv
# 26 twaddle
# 47 twenty
# 120 twice
# 29 twin
# 99 twist
# 129 twisted
# 135 twists
# 1168 two
# 28 twohy
# 81 type
# 38 types
# 130 typical
# 166 ugly
# 29 uh
# 141 ultimate
# 446 ultimately
# 46 ultra
# 25 un
# 27 unabashed
# 43 unabashedly
# 28 unable
# 25 unassuming
# 38 unbelievable
# 27 unblinking
# 43 uncanny
# 33 uncertain
# 28 unchecked
# 31 uncomfortable
# 27 uncomfortably
# 33 uncommonly
# 56 uncompromising
# 28 unconditional
# 42 unconventional
# 56 unconvincing
# 40 undead
# 57 undeniable
# 74 undeniably
# 46 underbelly
# 26 undercover
# 26 undercurrent
# 28 undercuts
# 27 underdogs
# 24 underlying
# 152 understand
# 73 understanding
# 41 understands
# 44 understated
# 26 undone
# 24 undoubtedly
# 43 uneasy
# 104 uneven
# 23 uneventful
# 153 unexpected
# 40 unexpectedly
# 61 unfaithful
# 57 unflinching
# 57 unfocused
# 32 unfolding
# 61 unfolds
# 48 unforced
# 58 unfortunately
# 41 unfulfilling
# 135 unfunny
# 29 unhappy
# 34 unimaginable
# 58 unimaginative
# 56 uninspired
# 33 unintentional
# 59 unintentionally
# 26 uninteresting
# 142 unique
# 123 universal
# 31 universe
# 29 unknown
# 31 unless
# 49 unlikable
# 44 unlike
# 81 unlikely
# 25 unlimited
# 80 unnecessary
# 47 unnerving
# 49 unoriginal
# 75 unpleasant
# 58 unpredictable
# 25 unrewarding
# 38 unsatisfying
# 46 unsentimental
# 177 unsettling
# 34 unsuspecting
# 25 unsympathetic
# 38 untalented
# 88 unusual
# 44 unusually
# 27 upbeat
# 24 update
# 56 uplifting
# 133 upon
# 38 upper
# 111 ups
# 172 urban
# 69 urge
# 61 urgency
# 1218 us
# 163 use
# 168 used
# 33 useless
# 139 uses
# 50 using
# 204 usual
# 125 usually
# 65 utter
# 129 utterly
# 33 vacuum
# 58 vague
# 30 vaguely
# 26 vain
# 34 valley
# 31 valuable
# 118 value
# 86 values
# 113 vampire
# 70 van
# 41 vanity
# 54 vapid
# 66 variety
# 110 various
# 29 vast
# 26 veers
# 104 vehicle
# 48 vein
# 25 veneer
# 42 venice
# 45 venture
# 37 verbal
# 291 version
# 31 versions
# 39 versus
# 52 verve
# 27 veteran
# 27 via
# 55 vibrant
# 25 vice
# 60 victim
# 68 victims
# 470 video
# 52 videos
# 23 videotape
# 55 vietnam
# 39 vietnamese
# 207 view
# 30 viewed
# 230 viewer
# 226 viewers
# 147 viewing
# 28 vignettes
# 76 villain
# 36 villainous
# 34 villains
# 24 vin
# 62 vincent
# 61 vintage
# 225 violence
# 105 violent
# 104 virtually
# 37 virtues
# 91 visceral
# 194 vision
# 48 visit
# 450 visual
# 193 visually
# 105 visuals
# 63 vital
# 40 vitality
# 90 vivid
# 55 vividly
# 139 voice
# 24 voices
# 25 von
# 98 vs
# 36 vu
# 71 vulgar
# 23 vulgarity
# 24 vulnerable
# 88 wacky
# 24 wade
# 89 wait
# 119 waiting
# 52 wake
# 32 waking
# 27 wal
# 64 walk
# 43 walked
# 40 walking
# 54 wall
# 58 wallace
# 44 wallet
# 27 wallop
# 41 walsh
# 69 wannabe
# 451 want
# 137 wanted
# 48 wanting
# 137 wants
# 578 war
# 36 warfare
# 172 warm
# 32 warmed
# 145 warmth
# 40 warner
# 67 warning
# 34 warrior
# 29 warriors
# 95 wars
# 25 wartime
# 71 washington
# 128 waste
# 78 wasted
# 628 watch
# 129 watchable
# 539 watching
# 160 water
# 48 waters
# 27 wattage
# 91 wave
# 26 waves
# 1529 way
# 25 waydowntown
# 256 ways
# 91 weak
# 26 weaknesses
# 44 wear
# 51 wearing
# 53 wears
# 26 weary
# 25 weave
# 44 web
# 28 website
# 98 wedding
# 101 week
# 78 weeks
# 25 weepy
# 79 weight
# 41 weighty
# 130 weird
# 38 weirdly
# 46 weirdness
# 171 welcome
# 1535 well
# 27 welles
# 34 wells
# 30 welsh
# 25 wendigo
# 72 went
# 26 wertmuller
# 29 wesley
# 65 west
# 53 western
# 49 wet
# 46 whale
# 88 whatever
# 41 whenever
# 211 whether
# 29 whimper
# 58 whimsical
# 50 whimsy
# 26 whiny
# 30 whip
# 211 white
# 26 whodunit
# 336 whole
# 38 wholesome
# 53 wholly
# 359 whose
# 50 wickedly
# 103 wide
# 142 wife
# 36 wilco
# 182 wild
# 77 wilde
# 24 wildlife
# 112 wildly
# 26 william
# 115 williams
# 73 willing
# 29 willingness
# 43 willis
# 47 wilson
# 122 win
# 80 wind
# 58 window
# 47 winds
# 26 windtalkers
# 28 wing
# 59 winner
# 36 winners
# 152 winning
# 48 wins
# 32 winter
# 26 wire
# 25 wisdom
# 124 wise
# 134 wish
# 24 wishing
# 24 wistful
# 306 wit
# 93 witch
# 46 witherspoon
# 78 within
# 872 without
# 41 witless
# 40 witness
# 27 witnessed
# 25 witnesses
# 44 witted
# 131 witty
# 254 wo
# 25 woefully
# 32 wollter
# 326 woman
# 489 women
# 115 wonder
# 186 wonderful
# 79 wonderfully
# 51 wondering
# 34 wonders
# 27 wondrous
# 68 woo
# 28 wood
# 34 wooden
# 55 woody
# 161 word
# 158 words
# 1272 work
# 93 worked
# 25 workers
# 228 working
# 24 workplace
# 458 works
# 997 world
# 61 worn
# 25 worry
# 150 worse
# 311 worst
# 503 worth
# 102 worthwhile
# 168 worthy
# 1151 would
# 27 wound
# 63 wow
# 47 wrapped
# 33 wreck
# 61 wrenching
# 31 wrestling
# 423 writer
# 57 writers
# 206 writing
# 280 written
# 222 wrong
# 51 wrote
# 87 wry
# 37 xxx
# 146 ya
# 29 yard
# 89 yarn
# 23 yawning
# 819 year
# 54 yearning
# 539 years
# 28 yellow
# 70 yes
# 45 yesterday
# 547 yet
# 42 yiddish
# 208 york
# 28 yorker
# 634 young
# 68 younger
# 46 youth
# 30 youthful
# 24 zany
# 33 zeal
# 29 zero
# 37 zhang
# 29 zombie
# 114 zone

# %%
train_df['Sentiment'].fillna(0,inplace = True)
train_df['Sentiment'].isna().sum()
# Out:
# 0

# %%
train_feat_array.shape
# Out:
# (156060, 5000)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 100)

mod = rf.fit(train_feat,train_df['Sentiment'])

# %%
length = len(test_df['Phrase'])

cleaned_test_phrases = []

for i in range(0, length):
  cleaned_test_phrases.append(clean_words(test_df['Phrase'][i]))
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
cleaned_test_phrases
# Out:
# ['intermittently pleasing mostly routine effort',
#  'intermittently pleasing mostly routine effort',
#  '',
#  'intermittently pleasing mostly routine effort',
#  'intermittently pleasing mostly routine',
#  'intermittently pleasing',
#  'intermittently pleasing',
#  'intermittently',
#  'pleasing',
#  '',
#  'mostly routine',
#  'mostly',
#  'routine',
#  'effort',
#  '',
#  'kidman really thing worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies post full monty world',
#  'kidman',
#  'really thing worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies post full monty world',
#  'really thing worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies post full monty world',
#  'really',
#  '',
#  'really',
#  'thing worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies post full monty world',
#  'thing',
#  '',
#  'thing',
#  '',
#  'thing',
#  'worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies post full monty world',
#  '',
#  'worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies post full monty world',
#  'worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves yet another example sad decline british comedies',
#  'worth watching birthday girl film stage trained jez butterworth lrb mojo rrb serves',
#  'worth',
#  '',
#  'worth',
#  'watching birthday girl film stage trained jez butterworth lrb mojo rrb serves',
#  'watching birthday girl film',
#  'watching',
#  'birthday girl film',
#  '',
#  'birthday girl film',
#  'birthday girl',
#  'birthday girl',
#  'birthday',
#  'girl',
#  '',
#  'film',
#  '',
#  'film',
#  'stage trained jez butterworth lrb mojo rrb serves',
#  '',
#  'stage trained jez butterworth lrb mojo rrb serves',
#  'stage trained jez butterworth lrb mojo rrb',
#  'stage trained jez butterworth',
#  'stage trained jez butterworth',
#  'stage trained',
#  'jez butterworth',
#  'jez',
#  'butterworth',
#  'lrb mojo rrb',
#  'lrb',
#  'mojo rrb',
#  'mojo',
#  'rrb',
#  'serves',
#  'serves',
#  'yet another example sad decline british comedies',
#  '',
#  'yet another example sad decline british comedies',
#  'yet',
#  'another example sad decline british comedies',
#  'another example',
#  'another',
#  'example',
#  'sad decline british comedies',
#  '',
#  'sad decline british comedies',
#  'sad decline',
#  'sad decline',
#  'sad',
#  'decline',
#  'british comedies',
#  'british comedies',
#  'british',
#  'comedies',
#  'post full monty world',
#  'post full monty world',
#  'post full monty world',
#  'post full',
#  'monty world',
#  'monty',
#  'world',
#  'get rhythm movie becomes heady experience',
#  'get rhythm',
#  '',
#  'get rhythm',
#  '',
#  'get rhythm',
#  'get',
#  'rhythm',
#  '',
#  'rhythm',
#  '',
#  'rhythm',
#  'movie becomes heady experience',
#  '',
#  'movie becomes heady experience',
#  'movie',
#  'movie',
#  'becomes heady experience',
#  'becomes heady experience',
#  'becomes',
#  'heady experience',
#  'heady experience',
#  'heady',
#  'experience',
#  'kept wishing watching documentary wartime navajos accomplished instead specious hollywood hoo ha',
#  '',
#  'kept wishing watching documentary wartime navajos accomplished instead specious hollywood hoo ha',
#  'kept wishing watching documentary wartime navajos accomplished instead specious hollywood hoo ha',
#  'kept',
#  'wishing watching documentary wartime navajos accomplished instead specious hollywood hoo ha',
#  'wishing',
#  'watching documentary wartime navajos accomplished instead specious hollywood hoo ha',
#  'watching documentary wartime navajos',
#  'watching documentary wartime navajos',
#  'watching documentary wartime navajos',
#  '',
#  'watching documentary wartime navajos',
#  'documentary wartime navajos',
#  'documentary',
#  'documentary',
#  'wartime navajos',
#  '',
#  'wartime navajos',
#  'wartime navajos',
#  'wartime',
#  'navajos',
#  '',
#  'accomplished instead specious hollywood hoo ha',
#  '',
#  'accomplished instead specious hollywood hoo ha',
#  '',
#  'accomplished instead specious hollywood hoo ha',
#  'accomplished',
#  'instead specious hollywood hoo ha',
#  'instead',
#  'specious hollywood hoo ha',
#  'specious hollywood hoo ha',
#  'specious',
#  '',
#  'specious',
#  '',
#  'specious',
#  'hollywood hoo ha',
#  'hollywood',
#  'hoo ha',
#  'kinnear n aim sympathy rather delivers performance striking skill depth',
#  'kinnear',
#  'n aim sympathy rather delivers performance striking skill depth',
#  'n aim sympathy rather delivers performance striking skill depth',
#  'n aim sympathy',
#  'n aim sympathy',
#  'n aim sympathy',
#  'n',
#  '',
#  'n',
#  'aim sympathy',
#  'aim',
#  'sympathy',
#  '',
#  'sympathy',
#  '',
#  'sympathy',
#  'rather delivers performance striking skill depth',
#  'rather',
#  'delivers performance striking skill depth',
#  'delivers',
#  'performance striking skill depth',
#  'performance',
#  'performance',
#  'striking skill depth',
#  'striking skill depth',
#  'striking',
#  'skill depth',
#  'skill',
#  'skill',
#  'depth',
#  'ends well sort frenzied comic moments never click',
#  'ends well sort frenzied comic moments never click',
#  'ends well sort',
#  'ends well sort',
#  'ends well sort',
#  'ends well sort',
#  'ends well',
#  'ends well',
#  'ends',
#  'well',
#  'sort',
#  'sort',
#  'frenzied comic moments never click',
#  'frenzied comic moments',
#  'frenzied comic moments',
#  'frenzied',
#  'comic moments',
#  'comic',
#  'moments',
#  'never click',
#  'never',
#  'click',
#  'hoot half great way american people see candidate like giving cent stump speech',
#  '',
#  'hoot half great way american people see candidate like giving cent stump speech',
#  'hoot half great way american people see candidate like giving cent stump speech',
#  'hoot half great way american people',
#  'hoot half great way american people',
#  'hoot half',
#  'hoot half',
#  'hoot half',
#  'hoot',
#  'hoot',
#  'hoot',
#  'half',
#  'half',
#  'great way american people',
#  'great way',
#  'great way',
#  'great',
#  'way',
#  'american people',
#  'american people',
#  'american people',
#  'american',
#  'people',
#  'see candidate like giving cent stump speech',
#  '',
#  'see candidate like giving cent stump speech',
#  'see',
#  'candidate like giving cent stump speech',
#  'candidate like giving cent stump speech',
#  'candidate',
#  'candidate',
#  'like giving cent stump speech',
#  'like giving cent stump speech',
#  'like',
#  'giving cent stump speech',
#  '',
#  'giving cent stump speech',
#  '',
#  'giving cent stump speech',
#  '',
#  '',
#  'giving cent stump speech',
#  'giving',
#  'cent stump speech',
#  'cent stump speech',
#  '',
#  'cent stump speech',
#  'cent',
#  'stump speech',
#  'stump',
#  'speech',
#  'weight piece unerring professionalism chilly production fascination embedded lurid topic prove recommendation enough',
#  'weight piece unerring professionalism chilly production fascination embedded lurid topic',
#  'weight',
#  'weight',
#  'piece unerring professionalism chilly production fascination embedded lurid topic',
#  'piece unerring professionalism chilly production fascination embedded lurid topic',
#  'piece',
#  'piece',
#  'piece',
#  'unerring professionalism chilly production fascination embedded lurid topic',
#  'unerring professionalism chilly production',
#  'unerring professionalism chilly production',
#  'unerring professionalism chilly production',
#  'unerring professionalism',
#  'unerring professionalism',
#  'unerring',
#  'professionalism',
#  'chilly production',
#  'chilly production',
#  'chilly production',
#  'chilly',
#  'production',
#  'fascination embedded lurid topic',
#  'fascination',
#  'fascination',
#  'embedded lurid topic',
#  'embedded',
#  'lurid topic',
#  'lurid topic',
#  'lurid topic',
#  'lurid',
#  'topic',
#  'prove recommendation enough',
#  'prove recommendation enough',
#  'prove recommendation',
#  'prove',
#  'recommendation',
#  'enough',
#  'film contains good jokes good scenes barely moment carvey saturday night live honed mimicry rises level embarrassment',
#  'film',
#  'contains good jokes good scenes barely moment carvey saturday night live honed mimicry rises level embarrassment',
#  'contains good jokes good scenes barely moment carvey saturday night live honed mimicry rises level embarrassment',
#  'contains',
#  'good jokes good scenes barely moment carvey saturday night live honed mimicry rises level embarrassment',
#  'good jokes good scenes barely moment',
#  'good jokes good scenes',
#  'good jokes good scenes',
#  'good jokes',
#  'good jokes',
#  '',
#  'good jokes',
#  'good',
#  'jokes',
#  'good scenes',
#  'good scenes',
#  'scenes',
#  'barely moment',
#  'barely',
#  'moment',
#  'moment',
#  'carvey saturday night live honed mimicry rises level embarrassment',
#  'carvey saturday night live honed mimicry rises level embarrassment',
#  'carvey saturday night live honed mimicry',
#  'carvey',
#  'carvey',
#  'saturday night live honed mimicry',
#  'saturday',
#  'night live honed mimicry',
#  'night',
#  'live honed mimicry',
#  'live honed',
#  'mimicry',
#  'rises level embarrassment',
#  'rises',
#  'level embarrassment',
#  '',
#  'level embarrassment',
#  'level',
#  'level',
#  'embarrassment',
#  'embarrassment',
#  'offbeat sometimes gross surprisingly appealing animated film true meaning holidays',
#  'offbeat sometimes gross surprisingly appealing animated film true meaning holidays',
#  'offbeat sometimes gross surprisingly appealing animated film',
#  'offbeat sometimes gross surprisingly appealing animated film',
#  'offbeat',
#  'sometimes gross surprisingly appealing animated film',
#  'sometimes gross surprisingly appealing animated film',
#  'sometimes gross surprisingly appealing',
#  'sometimes gross',
#  'sometimes gross',
#  'sometimes',
#  'gross',
#  'surprisingly appealing',
#  'surprisingly',
#  'appealing',
#  'animated film',
#  'animated',
#  'true meaning holidays',
#  'true meaning holidays',
#  'true meaning',
#  'true meaning',
#  'true',
#  'meaning',
#  'holidays',
#  'holidays',
#  'holidays',
#  'suggests wide ranging effects media manipulation kind reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'suggests wide ranging effects media manipulation kind reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'suggests wide ranging effects media manipulation kind reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'suggests wide ranging effects media manipulation',
#  'suggests wide ranging effects media manipulation',
#  'suggests',
#  'wide ranging effects media manipulation',
#  'wide ranging effects',
#  'wide ranging effects',
#  'wide ranging',
#  'effects',
#  'media manipulation',
#  'media manipulation',
#  'media',
#  'manipulation',
#  'kind reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  '',
#  'kind reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'kind',
#  'kind',
#  'reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'reporting done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'reporting',
#  'done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'done supposedly liberal media intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'done supposedly liberal media',
#  'done supposedly liberal media',
#  'done',
#  'supposedly liberal media',
#  'supposedly liberal media',
#  'supposedly liberal media',
#  'supposedly liberal',
#  'supposedly',
#  'liberal',
#  'intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'intimate ultimately tragic heartache maverick individuals like hatfield hicks',
#  'intimate ultimately tragic heartache',
#  'intimate ultimately tragic heartache',
#  'intimate ultimately tragic',
#  'intimate',
#  'intimate',
#  'ultimately tragic',
#  'ultimately',
#  'tragic',
#  'heartache',
#  'maverick individuals like hatfield hicks',
#  'maverick individuals like hatfield hicks',
#  'maverick individuals',
#  'maverick',
#  'individuals',
#  'like hatfield hicks',
#  'hatfield hicks',
#  'hatfield',
#  'hatfield',
#  'hicks',
#  'tweedy talks canning stockbroker repairing pool yearn airborne tv sets nude groupies nod liven things',
#  'tweedy talks canning stockbroker repairing pool',
#  'tweedy talks canning stockbroker repairing pool',
#  'tweedy',
#  'talks canning stockbroker repairing pool',
#  'talks',
#  'canning stockbroker repairing pool',
#  'canning stockbroker repairing pool',
#  'canning stockbroker',
#  'canning stockbroker',
#  'canning',
#  'stockbroker',
#  '',
#  'stockbroker',
#  'repairing pool',
#  'repairing',
#  'pool',
#  'pool',
#  'yearn airborne tv sets nude groupies nod liven things',
#  'yearn airborne tv sets nude groupies nod liven things',
#  'yearn airborne tv sets nude groupies nod liven things',
#  'yearn airborne tv sets nude groupies nod liven things',
#  'yearn',
#  'airborne tv sets nude groupies nod liven things',
#  'airborne tv sets nude groupies nod liven things',
#  'airborne tv sets',
#  'airborne tv sets',
#  'airborne tv sets',
#  '',
#  'airborne tv sets',
#  'airborne',
#  'tv sets',
#  'tv',
#  'sets',
#  '',
#  'nude groupies nod liven things',
#  'nude groupies',
#  'nude',
#  'groupies',
#  'nod liven things',
#  '',
#  'nod liven things',
#  'nod liven things',
#  'nod',
#  'liven things',
#  'liven things',
#  'liven things',
#  'liven',
#  'things',
#  '',
#  'failed connections divine secrets ya ya sisterhood nurturing gauzy dithering way',
#  'failed connections',
#  'failed connections',
#  'failed connections',
#  'failed connections',
#  'failed',
#  'connections',
#  'divine secrets ya ya sisterhood nurturing gauzy dithering way',
#  'divine secrets ya ya sisterhood nurturing gauzy dithering way',
#  'divine secrets ya ya sisterhood',
#  'divine secrets',
#  'divine',
#  'secrets',
#  'ya ya sisterhood',
#  'ya ya sisterhood',
#  'ya ya sisterhood',
#  'ya ya',
#  'sisterhood',
#  'nurturing gauzy dithering way',
#  'nurturing gauzy dithering way',
#  'nurturing',
#  'nurturing',
#  'nurturing',
#  'gauzy dithering way',
#  'gauzy dithering way',
#  'gauzy',
#  'gauzy',
#  'gauzy',
#  'dithering way',
#  'dithering',
#  'would hard think recent movie worked hard achieve little fun',
#  'would hard think recent movie worked hard achieve little fun',
#  'would hard think recent movie worked hard achieve little fun',
#  'would',
#  'hard think recent movie worked hard achieve little fun',
#  '',
#  'hard think recent movie worked hard achieve little fun',
#  'hard',
#  'think recent movie worked hard achieve little fun',
#  'think recent movie worked hard achieve little fun',
#  'think',
#  'recent movie worked hard achieve little fun',
#  'recent movie worked hard achieve little fun',
#  'recent movie',
#  'recent movie',
#  'recent',
#  'worked hard achieve little fun',
#  'worked hard achieve little fun',
#  '',
#  'worked hard achieve little fun',
#  'worked',
#  'hard achieve little fun',
#  'hard achieve little fun',
#  'achieve little fun',
#  'achieve little fun',
#  'achieve',
#  'little fun',
#  'little fun',
#  'little',
#  'fun',
#  'story structure well honed',
#  'story structure',
#  'story structure',
#  'story',
#  'story',
#  'structure',
#  'well honed',
#  'well honed',
#  '',
#  'well honed',
#  'chilling uncommercial look mind jeffrey dahmer serial killer',
#  'chilling uncommercial',
#  'chilling',
#  'chilling',
#  'uncommercial',
#  'look mind jeffrey dahmer serial killer',
#  'look mind jeffrey dahmer serial killer',
#  'look',
#  'mind jeffrey dahmer serial killer',
#  'mind jeffrey dahmer serial killer',
#  'mind',
#  'mind',
#  'jeffrey dahmer serial killer',
#  'jeffrey dahmer serial killer',
#  'jeffrey dahmer',
#  'jeffrey dahmer',
#  'jeffrey',
#  'dahmer',
#  'serial killer',
#  'serial',
#  'killer',
#  'movie plain old monster',
#  'movie plain old monster',
#  'plain old monster',
#  'plain old monster',
#  '',
#  '',
#  'plain old monster',
#  'plain old monster',
#  'plain old',
#  'plain',
#  'old',
#  'monster',
#  'film relationship actual tension christmas tree flocking spray actual snow poor durable imitation',
#  'film relationship actual tension',
#  'film relationship',
#  'film',
#  'film',
#  'relationship',
#  'actual tension',
#  'actual tension',
#  'actual',
#  'tension',
#  'christmas tree flocking spray actual snow poor durable imitation',
#  'christmas tree flocking spray actual snow poor durable imitation',
#  'christmas tree flocking spray actual snow poor durable imitation',
#  '',
#  'christmas tree flocking spray actual snow poor durable imitation',
#  'christmas tree flocking spray actual snow poor durable imitation',
#  'christmas tree flocking spray actual snow poor durable imitation',
#  'christmas tree flocking spray',
#  'christmas tree flocking',
#  'christmas tree',
#  'flocking',
#  'spray',
#  'spray',
#  'spray',
#  'spray',
#  '',
#  'actual snow poor durable imitation',
#  'actual snow poor durable imitation',
#  'actual snow poor durable imitation',
#  'actual snow',
#  'actual snow',
#  'snow',
#  '',
#  'poor durable imitation',
#  'poor durable imitation',
#  'poor durable',
#  'poor',
#  'durable',
#  '',
#  'durable',
#  'durable',
#  '',
#  'durable',
#  'imitation',
#  'depressing confirmation everything us n object description unelected suspected along george w bush incurious uncharismatic overgrown frat boy mean streak mile wide',
#  'depressing confirmation everything us n object description unelected suspected along george w bush incurious uncharismatic overgrown frat boy mean streak mile wide',
#  'depressing confirmation everything us n object description unelected suspected along',
#  'depressing confirmation everything us n object description unelected suspected along',
#  'depressing confirmation everything us n object description unelected',
#  'depressing confirmation',
#  'depressing confirmation',
#  'depressing',
#  'confirmation',
#  'everything us n object description unelected',
#  'everything us n object description unelected',
#  'everything',
#  'us n object description unelected',
#  'us',
#  '',
#  'us',
#  'us',
#  'n object description unelected',
#  '',
#  'n object description unelected',
#  'n',
#  '',
#  'object description unelected',
#  'object',
#  'description unelected',
#  'description unelected',
#  'description unelected',
#  'description',
#  'unelected',
#  '',
#  'unelected',
#  'unelected',
#  '',
#  'suspected along',
#  '',
#  'suspected along',
#  'suspected',
#  'along',
#  'along',
#  'george w bush incurious uncharismatic overgrown frat boy mean streak mile wide',
#  'george w bush',
#  'george',
#  'w bush',
#  'w',
#  'bush',
#  'incurious uncharismatic overgrown frat boy mean streak mile wide',
#  'incurious uncharismatic overgrown frat boy mean streak mile wide',
#  'incurious uncharismatic overgrown frat boy',
#  'incurious uncharismatic overgrown frat boy',
#  'incurious',
#  'uncharismatic overgrown frat boy',
#  'uncharismatic overgrown frat boy',
#  'uncharismatic',
#  'overgrown frat boy',
#  'overgrown frat boy',
#  'overgrown',
#  'frat boy',
#  'frat',
#  'boy',
#  'mean streak mile wide',
#  '',
#  'mean streak mile wide',
#  'mean streak mile',
#  'mean streak',
#  'mean streak',
#  'mean',
#  'streak',
#  'mile',
#  'mile',
#  'wide',
#  'n know music appreciate film easygoing blend comedy romance',
#  'n know music appreciate film easygoing blend comedy romance',
#  'n know music appreciate film easygoing blend comedy romance',
#  'know music appreciate film easygoing blend comedy romance',
#  'know music',
#  'know music',
#  'know music',
#  'know',
#  'music',
#  'music',
#  'appreciate film easygoing blend comedy romance',
#  'appreciate film easygoing blend comedy romance',
#  'appreciate',
#  'film easygoing blend comedy romance',
#  'film easygoing blend',
#  'film',
#  'easygoing blend',
#  'easygoing',
#  'blend',
#  'comedy romance',
#  'comedy romance',
#  'comedy',
#  'comedy',
#  'romance',
#  'however lacks grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'however',
#  'lacks grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'lacks grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'lacks grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'lacks grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'lacks',
#  'grandeur epic quality often associated stevenson tale well earlier disney efforts',
#  'grandeur',
#  'grandeur',
#  'epic quality often associated stevenson tale well earlier disney efforts',
#  'epic quality',
#  'epic quality',
#  'epic',
#  'quality',
#  'often associated stevenson tale well earlier disney efforts',
#  'often',
#  'associated stevenson tale well earlier disney efforts',
#  'associated',
#  'stevenson tale well earlier disney efforts',
#  'stevenson tale well',
#  'stevenson tale',
#  'stevenson tale',
#  'stevenson',
#  'stevenson',
#  'tale',
#  'well',
#  'well',
#  'earlier disney efforts',
#  'earlier disney efforts',
#  'earlier',
#  'disney efforts',
#  'disney',
#  'efforts',
#  'although occasionally static point resembling stage play film delivers solid mixture sweetness laughs',
#  'although occasionally static point resembling stage play',
#  'although',
#  'occasionally static point resembling stage play',
#  'occasionally',
#  'static point resembling stage play',
#  'static',
#  'point resembling stage play',
#  'point resembling stage play',
#  'point',
#  'point',
#  'resembling stage play',
#  'resembling stage play',
#  'resembling',
#  'stage play',
#  'stage play',
#  'stage',
#  'play',
#  'film delivers solid mixture sweetness laughs',
#  'film delivers solid mixture sweetness laughs',
#  'delivers solid mixture sweetness laughs',
#  'delivers solid mixture sweetness laughs',
#  'delivers solid mixture sweetness',
#  'delivers solid mixture sweetness',
#  'solid mixture sweetness',
#  'solid mixture',
#  'solid mixture',
#  'solid',
#  'mixture',
#  'sweetness',
#  'sweetness',
#  'laughs',
#  'occasionally funny overall limp fish water story',
#  'occasionally funny overall limp fish water',
#  'occasionally funny overall limp fish water',
#  'occasionally funny overall limp',
#  'occasionally funny',
#  'funny',
#  'overall limp',
#  'overall limp',
#  'overall limp',
#  'overall',
#  'limp',
#  'limp',
#  'fish water',
#  'story',
#  'nightmare date half formed wit done great disservice lack critical distance sad trust liberal arts college bumper sticker platitudes',
#  'nightmare date half formed wit',
#  'nightmare date',
#  'nightmare date',
#  'nightmare',
#  'date',
#  'half formed wit',
#  'half formed wit',
#  'half formed wit',
#  'half formed',
#  'wit',
#  'done great disservice lack critical distance sad trust liberal arts college bumper sticker platitudes',
#  'done great disservice lack critical distance sad trust liberal arts college bumper sticker platitudes',
#  'done great disservice lack critical distance sad trust',
#  'done great disservice',
#  'great disservice',
#  'great disservice',
#  'disservice',
#  'lack critical distance sad trust',
#  'lack critical distance sad trust',
#  'lack',
#  'lack',
#  'critical distance sad trust',
#  'critical distance sad trust',
#  'critical distance',
#  'critical distance',
#  'critical',
#  'distance',
#  'sad trust',
#  'sad trust',
#  'trust',
#  'liberal arts college bumper sticker platitudes',
#  'liberal arts college bumper sticker platitudes',
#  'arts college bumper sticker platitudes',
#  'arts',
#  'college bumper sticker platitudes',
#  'college',
#  'bumper sticker platitudes',
#  'bumper',
#  'sticker platitudes',
#  'sticker',
#  'platitudes',
#  'fitfully amusing romp nothing else appeal fans malcolm middle pubescent star frankie muniz',
#  'fitfully amusing',
#  'fitfully amusing',
#  'fitfully',
#  'amusing',
#  'romp nothing else appeal fans malcolm middle pubescent star frankie muniz',
#  'romp nothing else appeal fans malcolm middle pubescent star frankie muniz',
#  'romp',
#  'nothing else appeal fans malcolm middle pubescent star frankie muniz',
#  'nothing else appeal fans malcolm middle pubescent star frankie muniz',
#  'nothing else appeal fans malcolm middle pubescent star frankie muniz',
#  'nothing else',
#  'nothing else',
#  'nothing',
#  'else',
#  'appeal fans malcolm middle pubescent star frankie muniz',
#  'appeal fans malcolm middle pubescent star frankie muniz',
#  '',
#  'appeal fans malcolm middle pubescent star frankie muniz',
#  'appeal',
#  'fans malcolm middle pubescent star frankie muniz',
#  'fans malcolm middle pubescent star frankie muniz',
#  'fans',
#  'malcolm middle pubescent star frankie muniz',
#  'malcolm middle pubescent star frankie muniz',
#  'malcolm middle',
#  'malcolm middle',
#  'malcolm',
#  'middle',
#  'middle',
#  'middle',
#  'pubescent star frankie muniz',
#  'pubescent star',
#  'pubescent star',
#  'pubescent star',
#  'pubescent',
#  'star',
#  'frankie muniz',
#  'frankie',
#  'muniz',
#  'spy funny lrb enough rrb exciting lrb enough rrb would fairly simple forgive financial extortion trying reap moviegoing public',
#  'spy funny lrb enough rrb exciting lrb enough rrb would fairly simple forgive financial extortion',
#  'spy funny lrb enough rrb exciting lrb enough rrb',
#  'spy funny lrb enough rrb exciting lrb enough rrb',
#  'spy',
#  'spy',
#  'funny lrb enough rrb exciting lrb enough rrb',
#  '',
#  'funny lrb enough rrb exciting lrb enough rrb',
#  'funny lrb enough rrb',
#  'funny lrb enough rrb',
#  'lrb enough rrb',
#  'enough rrb',
#  'exciting lrb enough rrb',
#  'exciting',
#  'would fairly simple forgive financial extortion',
#  '',
#  'would fairly simple forgive financial extortion',
#  'would fairly simple forgive financial extortion',
#  'fairly simple forgive financial extortion',
#  'fairly simple forgive financial extortion',
#  'fairly',
#  'simple forgive financial extortion',
#  'simple',
#  'forgive financial extortion',
#  'forgive financial extortion',
#  'forgive',
#  'financial extortion',
#  'financial extortion',
#  'financial',
#  'extortion',
#  'trying reap moviegoing public',
#  'trying reap moviegoing public',
#  'trying reap moviegoing public',
#  'trying reap moviegoing public',
#  'trying',
#  'reap moviegoing public',
#  'reap moviegoing public',
#  'reap',
#  'moviegoing public',
#  'moviegoing public',
#  'moviegoing public',
#  'moviegoing',
#  'public',
#  'borrows many literary cinematic sources future world feels absolutely deja vu',
#  'borrows many literary cinematic sources future world feels absolutely deja vu',
#  'borrows',
#  'many literary cinematic sources future world feels absolutely deja vu',
#  'many literary cinematic sources future world feels absolutely deja vu',
#  'many literary cinematic sources',
#  'many',
#  '',
#  'many',
#  'literary cinematic sources',
#  'literary',
#  'cinematic sources',
#  'cinematic sources',
#  'cinematic',
#  'sources',
#  'future world feels absolutely deja vu',
#  'future world feels absolutely deja vu',
#  'future world',
#  'future world',
#  'future',
#  'feels absolutely deja vu',
#  'feels',
#  'absolutely deja vu',
#  'absolutely',
#  'deja vu',
#  'deja',
#  'vu',
#  'despite title amy orgasm porno though tedious one',
#  'despite title',
#  'despite',
#  'title',
#  'title',
#  'amy orgasm porno though tedious one',
#  'amy orgasm porno though tedious one',
#  'amy orgasm',
#  'amy',
#  'amy',
#  'orgasm',
#  'porno though tedious one',
#  'porno though tedious one',
#  'porno',
#  'porno',
#  '',
#  'porno',
#  'porno',
#  'though tedious one',
#  'though',
#  'tedious one',
#  'tedious one',
#  'tedious one',
#  'tedious one',
#  'tedious',
#  'one',
#  'one',
#  'dogged good parents vain jia defoliation ego make film touching despite doldrums',
#  'dogged good parents vain jia defoliation ego make film touching despite doldrums',
#  'dogged good parents vain jia defoliation ego make film touching despite doldrums',
#  'dogged good parents vain jia defoliation ego',
#  'dogged good parents vain jia defoliation ego',
#  'dogged',
#  'good parents vain jia defoliation ego',
#  'good parents vain jia defoliation',
#  'good parents vain jia',
#  'good',
#  'parents vain jia',
#  'parents vain jia',
#  'parents vain jia',
#  'parents',
#  'parents',
#  'parents',
#  'vain jia',
#  '',
#  'vain jia',
#  'vain',
#  'jia',
#  '',
#  'jia',
#  ...]

# %%
test_feat = vectorizer.transform(cleaned_test_phrases)
test_feat_array = test_feat.toarray()

# Use the random forest to make sentiment label predictions
result = rf.predict(test_feat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-75fff34f9656> in <module>()
#       7 # Copy the results to a pandas dataframe with an "id" column and
#       8 # a "sentiment" column
# ----> 9 output = pd.DataFrame( data={"PhraseId":test["PhraseId"], "Sentiment":result} )
#      10
#      11 # Use pandas to write the comma-separated output file
#
# NameError: name 'test' is not defined

# %%
# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"PhraseId":test_df["PhraseId"], "Sentiment":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "Bag_of_Words_model.csv", index=False, quoting=3 )

# %%
from sklearn.svm import LinearSVC
from sklearn.preprocessing import normalize

# %%
train_feat_norm = normalize(train_feat)
test_feat_norm = normalize(test_feat)

# %%
train_feat_norm
# Out:
# <156060x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 508653 stored elements in Compressed Sparse Row format>

# %%
svm_mod = LinearSVC(random_state=0)

# %%
svm_mod.fit(train_feat_norm,train_df['Sentiment'])
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#           verbose=0)

# %%
svm_pred = svm_mod.predict(test_feat_norm)

# %%
# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"PhraseId":test_df["PhraseId"], "Sentiment":svm_pred} )

# Use pandas to write the comma-separated output file
output.to_csv( "Bag_of_Words_SVM_model.csv", index=False, quoting=3 )
